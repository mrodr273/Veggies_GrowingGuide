# %%
from bs4 import BeautifulSoup
import urllib
import urllib.request
import re

# %%
with urllib.request.urlopen('http://www.gardening.cornell.edu/homegardening/scene0391.html?fbclid=IwAR1ya1O5YcruAFWc9rEESONLuRaLqSZv4eC1ujaGVMmKCyB2l_KDLd4NZtU') as response:
                            html = response.read()

# %%
soup = BeautifulSoup(html,'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify())
# Out:
# <html>
#  <!-- Mirrored from explore.cornell.edu/scene.cfm?scene=home%20gardening&stop=HG%20%2D%20Find%20a%20Vegetable by HTTrack Website Copier/3.x [XR&CO'2006], Tue, 19 Sep 2006 18:39:57 GMT -->
#  <head>
#   <title>
#    Explore Cornell - Home Gardening - Vegetable Growing Guides
#   </title>
#   <!-- Begin Include : "/includes/style.cfm" -->
#   <style type="text/css">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -->
#   </style>
#   <link href="styles/screen.css" media="screen" rel="stylesheet" type="text/css"/>
#   <!-- End Include : "/includes/style.cfm" -->
#   <script language="Javascript" src="includes/main.js">
#   </script>
#  </head>
#  <body bgcolor="ffffff" leftmargin="0" link="000099" marginheight="0" marginwidth="0" rightmargin="0" topmargin="0">
#   <script type="text/javascript">
#
#
#
#
#
#
#
#
#   })();
#   </script>
#   <a name="top">
#    <center>
#     <!-- ---------------------------- include header -->
#     <script language="Javascript">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# // -->
#     </script>
#     <!-- begin header -->
#     <div id="cu-identity">
#      <div id="cu-logo">
#       <a href="http://www.cornell.edu/">
#        <img alt="Cornell University" border="0" height="45" src="images/cu_logo_unstyled.gif" width="166"/>
#       </a>
#      </div>
#      <div id="cu-search">
#       <a href="http://www.cornell.edu/search/">
#        Search Cornell
#       </a>
#      </div>
#     </div>
#     <!-- ****** begin id and navbar ****** -->
#     <center>
#      <table border="0" cellpadding="0" cellspacing="0" width="720">
#       <tr>
#        <td width="100%">
#         <table border="0" cellpadding="0" cellspacing="0" width="100%">
#          <tr>
#           <!-- conditional graphic slice top in -->
#           <!-- conditional graphic slice top in *** use for everything except feature, tour, and search -->
#           <td>
#            <a class="path" href="index.html">
#             <img alt="" border="0" height="15" src="feature_gardening/img/icon_t.gif" width="50"/>
#            </a>
#           </td>
#           <!-- conditional graphic slice top out -->
#          </tr>
#         </table>
#         <!-- conditional graphic slice top out -->
#        </td>
#       </tr>
#       <!-- conditional graphic slices in *** use for everything except feature, tour, and search *** any of these cells are fair game for design -->
#      </table>
#      <!-- ****** end id and navbar ****** -->
#      <!-- begin lower nav *** use for everything except feature, tour, and search -->
#      <table border="0" cellpadding="0" cellspacing="0" width="100%">
#       <tr>
#        <td align="middle" bgcolor="e7e7dd" valign="middle">
#         <table bgcolor="E7E7DD" border="0" cellpadding="0" cellspacing="0" width="720">
#          <tr>
#           <td bgcolor="ffffff">
#            <img height="1" src="img/dot_clear.gif" width="1"/>
#           </td>
#           <td bgcolor="CACABA" valign="top">
#            <a class="path" href="index.html">
#             <img alt="" border="0" height="50" src="feature_gardening/img/icon_b.gif" width="50"/>
#            </a>
#           </td>
#           <td bgcolor="ffffff">
#            <img height="1" src="img/dot_clear.gif" width="1"/>
#           </td>
#           <td>
#            <img height="1" src="img/dot_clear.gif" width="10"/>
#           </td>
#           <td>
#            <!-- specking width=100% is logical but breaks on ie4.5/aol5 mac, so spec table below -->
#            <table border="0" cellpadding="1" cellspacing="0" width="657">
#             <tr>
#              <td colspan="2">
#               <img height="4" src="img/dot_clear.gif" width="1"/>
#              </td>
#             </tr>
#             <tr>
#              <td colspan="2">
#               <table border="0" cellpadding="0" cellspacing="0">
#                <tr>
#                 <td>
#                  <div class="path">
#                   <a class="path" href="index.html">
#                    Home Gardening
#                   </a>
#                  </div>
#                 </td>
#                 <td>
#                  <img height="12" src="img/header/arrow_right.gif" width="15"/>
#                 </td>
#                </tr>
#               </table>
#              </td>
#             </tr>
#             <tr>
#              <td colspan="2">
#               <img height="3" src="img/dot_clear.gif" width="1"/>
#              </td>
#             </tr>
#             <tr>
#              <td width="100%">
#               <div class="pagetitle">
#                <b>
#                 Vegetable Growing Guides
#                </b>
#               </div>
#              </td>
#              <!-- start webring -->
#              <td align="right" nowrap="">
#              </td>
#              <!-- end webring -->
#             </tr>
#             <tr>
#              <td colspan="2">
#               <img height="4" src="img/dot_clear.gif" width="1"/>
#              </td>
#             </tr>
#            </table>
#           </td>
#
#
# 	-->
#          </tr>
#         </table>
#        </td>
#       </tr>
#      </table>
#      <!-- end lower nav *** use for everything except feature, tour, and search -->
#     </center>
#     <!-- end header -->
#     <!-- ---------------------------- include header -->
#     <!-- begin UBER TABLE -->
#     <a name="v_1">
#     </a>
#     <table border="0" cellpadding="0" cellspacing="0" width="720">
#      <!-- begin MAIN ROW -->
#      <tr>
#       <td>
#        <img alt="" border="0" height="30" src="img/dot_clear.gif" width="1"/>
#       </td>
#      </tr>
#      <tr>
#       <td colspan="5" valign="top">
#        <!-- the colspan of this table cell is conditional: colspan=5 for 1 col, none for 2 col -->
#        <!-- ******** begin MAIN INCLUDE ******** -->
#        <table border="0" cellpadding="0" cellspacing="0" width="100%">
#         <!-- ********************************************************************* -->
#         <!-- ********************************************** BEGIN GALLERY TEMPLATE -->
#         <tr>
#          <td align="left" valign="top">
#           <!-- BEGIN BODY INCLUDE for ALL TYPES -->
#           <table border="0" cellpadding="0" cellspacing="0" width="100%">
#            <!-- begin set col widths -->
#            <tr>
#             <td>
#              <img alt="" height="5" src="img/dot_clear.gif" width="460"/>
#             </td>
#             <td>
#              <img alt="" height="1" src="img/dot_clear.gif" width="19"/>
#             </td>
#             <td>
#              <img alt="" height="1" src="img/dot_clear.gif" width="1"/>
#             </td>
#             <td>
#              <img alt="" height="1" src="img/dot_clear.gif" width="30"/>
#             </td>
#             <td>
#              <img alt="" height="1" src="img/dot_clear.gif" width="210"/>
#             </td>
#            </tr>
#            <!-- end set col widths -->
#            <tr>
#             <td valign="top">
#              <table border="0" cellpadding="0" cellspacing="0" width="100%">
#               <tr>
#                <td valign="top" width="100%">
#                 <div class="normal">
#                  <b>
#                   Guides to 58 garden vegetables...
#                  </b>
#                  <br/>
#                  Each profile contains a detailed description and growing instructions, site and soil requirements, varieties, and solutions for managing pests and diseases.
#                 </div>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="10"/>
#                </td>
#                <td valign="top">
#                 <img alt="" height="97" src="feature_gardening/img/gg_vegetables.jpg" width="158"/>
#                </td>
#               </tr>
#              </table>
#             </td>
#             <td>
#             </td>
#             <td background="img/bg_dots.gif">
#              <img alt="" height="1" src="img/dot_clear.gif" width="1"/>
#             </td>
#             <td>
#             </td>
#             <td valign="top">
#              <table border="0" cellpadding="0" cellspacing="0" width="100%">
#               <tr>
#                <td valign="top">
#                 <div class="intro">
#                  <strong>
#                   See also:
#                   <br/>
#                   <a href="http://vegvariety.cce.cornell.edu/">
#                    Vegetable Varieties for Gardeners
#                   </a>
#                  </strong>
#                  <ul>
#                   <li>
#                    5,000+  variety profiles.
#                   </li>
#                   <li>
#                    Rate your favorites.
#                   </li>
#                   <li>
#                    Find seed sources.
#                   </li>
#                  </ul>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </ol> -->
#                 </div>
#                </td>
#               </tr>
#              </table>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <img alt="" height="20" src="img/dot_clear.gif" width="1"/>
#             </td>
#            </tr>
#            <tr>
#             <td bgcolor="cccccc" colspan="5">
#              <img alt="" height="1" src="img/dot_clear.gif" width="1"/>
#             </td>
#            </tr>
#            <tr>
#             <td bgcolor="F0F6E6" colspan="5">
#              <img alt="" height="5" src="img/dot_clear.gif" width="1"/>
#             </td>
#            </tr>
#            <tr>
#             <td bgcolor="F0F6E6" colspan="5">
#              <div class="normal">
#               <b>
#                Select a growing guide...
#               </b>
#              </div>
#             </td>
#            </tr>
#            <tr>
#             <td bgcolor="F0F6E6" colspan="5">
#              <img alt="" height="5" src="img/dot_clear.gif" width="1"/>
#             </td>
#            </tr>
#            <tr>
#             <td bgcolor="cccccc" colspan="5">
#              <img alt="" height="1" src="img/dot_clear.gif" width="1"/>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <img alt="" height="20" src="img/dot_clear.gif" width="1"/>
#             </td>
#            </tr>
#            <tr>
#             <td colspan="5">
#              <table border="0" cellpadding="0" cellspacing="0" width="100%">
#               <tr>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="150"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="19"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="1"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="20"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="150"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="19"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="1"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="20"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="150"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="19"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="1"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="20"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="150"/>
#                </td>
#               </tr>
#               <tr>
#                <td valign="top">
#                 <div class="intromuted">
#                  <a href="scenec09b.html">
#                   Artichoke - Globe
#                  </a>
#                  <br/>
#                  <a href="scene3693.html">
#                   Arugula
#                  </a>
#                  <br/>
#                  <a href="scenee3ed.html">
#                   Asparagus
#                  </a>
#                  <br/>
#                  <a href="scenef57c.html">
#                   Beans - Bush
#                  </a>
#                  <br/>
#                  (French, Green, String, Wax)
#                  <br/>
#                  <a href="scene8f63.html">
#                   Beans - Pole
#                  </a>
#                  <br/>
#                  (Green, String, Wax)
#                  <br/>
#                  <a href="scene18f3.html">
#                   Beets
#                  </a>
#                  <br/>
#                  <a href="scene0bdf.html">
#                   Bok Choy
#                  </a>
#                  <br/>
#                  (aka Pak Choy)
#                  <br/>
#                  <a href="scene91d8.html">
#                   Broccoli
#                  </a>
#                  <br/>
#                  <a href="scenec40b.html">
#                   Broccoli Raab
#                  </a>
#                  <br/>
#                  <a href="scene2520.html">
#                   Brussels Sprouts
#                  </a>
#                  <br/>
#                  <a href="scene5fdd.html">
#                   Cabbage - Common
#                  </a>
#                  <br/>
#                  <a href="scene5290.html">
#                   Cabbage - Chinese
#                  </a>
#                  <br/>
#                  <a href="scenea765.html">
#                   Carrots
#                  </a>
#                  <br/>
#                  <a href="scene595b.html">
#                   Cauliflower
#                  </a>
#                 </div>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="20"/>
#                </td>
#                <td background="img/bg_dots.gif">
#                 <img alt="" height="1" src="img/dot_clear.gif" width="1"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="20"/>
#                </td>
#                <td valign="top">
#                 <div class="intromuted">
#                  <a href="scene810e.html">
#                   Celeriac
#                  </a>
#                  <br/>
#                  <a href="sceneb528.html">
#                   Celery
#                  </a>
#                  <br/>
#                  <a href="scene0072.html">
#                   Chives
#                  </a>
#                  <br/>
#                  <a href="scene483b.html">
#                   Claytonia
#                  </a>
#                  <br/>
#                  <a href="scene6f80.html">
#                   Collards
#                  </a>
#                  <br/>
#                  <a href="scene05f6.html">
#                   Corn - Sweet
#                  </a>
#                  <br/>
#                  <a href="scene3673.html">
#                   Cress - Garden
#                  </a>
#                  <br/>
#                  <a href="scenef65b.html">
#                   Cucumbers
#                  </a>
#                  <br/>
#                  <a href="scene98cf.html">
#                   Cutting Chicory
#                  </a>
#                  <br/>
#                  <a href="scene26b5.html">
#                   Eggplant
#                  </a>
#                  <br/>
#                  <a href="scene18b1.html">
#                   Egyptian Onion
#                  </a>
#                  <br/>
#                  <a href="scenea2f3.html">
#                   Endive - Belgian
#                  </a>
#                  <br/>
#                  <a href="scene79ad.html">
#                   Endive - Common
#                  </a>
#                  <br/>
#                  <a href="scene568b.html">
#                   Garlic
#                  </a>
#                  <br/>
#                  <a href="scene57dc.html">
#                   Kale
#                  </a>
#                  <br/>
#                  <a href="scene1357.html">
#                   Kohlrabi
#                  </a>
#                  <br/>
#                  <a href="scene43f8.html">
#                   Leeks
#                  </a>
#                  <br/>
#                  <a href="scene9aa6.html">
#                   Lettuce
#                  </a>
#                 </div>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="20"/>
#                </td>
#                <td background="img/bg_dots.gif">
#                 <img alt="" height="1" src="img/dot_clear.gif" width="1"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="20"/>
#                </td>
#                <td valign="top">
#                 <div class="intromuted">
#                  <a href="scene144a.html">
#                   Melons
#                  </a>
#                  <br/>
#                  <a href="scene46c5.html">
#                   Mizuna
#                  </a>
#                  <br/>
#                  <a href="scene2b9a.html">
#                   Mustard Greens
#                  </a>
#                  <br/>
#                  <a href="scene4983.html">
#                   Onions - Common
#                  </a>
#                  <br/>
#                  (Yellow, White, Red, Green, Scallions)
#                  <br/>
#                  <a href="scene18b1.html">
#                   Onions - Egyptian
#                  </a>
#                  <br/>
#                  <a href="scene80ea.html">
#                   Orach
#                  </a>
#                  <br/>
#                  <a href="scene0bdf.html">
#                   Pak Choy
#                  </a>
#                  <br/>
#                  (aka Bok Choy)
#                  <br/>
#                  <a href="scenef2eb.html">
#                   Parsnips
#                  </a>
#                  <br/>
#                  <a href="scene9697.html">
#                   Peas
#                  </a>
#                  <br/>
#                  <a href="scene9c8a.html">
#                   Peppers
#                  </a>
#                  <br/>
#                  <a href="scenec6be.html">
#                   Potatoes
#                  </a>
#                  <br/>
#                  <a href="scene61ea.html">
#                   Pumpkins
#                  </a>
#                  <br/>
#                  <a href="scene1f17.html">
#                   Radicchio
#                  </a>
#                  <br/>
#                  <a href="scene341b.html">
#                   Radishes
#                  </a>
#                  <br/>
#                  <a href="scenec4d4.html">
#                   Rhubarb
#                  </a>
#                 </div>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="20"/>
#                </td>
#                <td background="img/bg_dots.gif">
#                 <img alt="" height="1" src="img/dot_clear.gif" width="1"/>
#                </td>
#                <td>
#                 <img alt="" height="1" src="img/dot_clear.gif" width="20"/>
#                </td>
#                <td valign="top">
#                 <div class="intromuted">
#                  <a href="scened5c9.html">
#                   Rutabagas
#                  </a>
#                  <br/>
#                  <a href="scene4983.html">
#                   Scallions
#                  </a>
#                  <br/>
#                  <a href="scene83de.html">
#                   Shallots
#                  </a>
#                  <br/>
#                  <a href="scene4c19.html">
#                   Spinach - Common
#                  </a>
#                  <br/>
#                  <a href="scene9529.html">
#                   Spinach - Malabar
#                  </a>
#                  <br/>
#                  <a href="scenef2e7.html">
#                   Spinach - New Zealand
#                  </a>
#                  <br/>
#                  <a href="scene6420.html">
#                   Squash - Summer
#                  </a>
#                  <br/>
#                  (Yellow, Zucchini, others)
#                  <br/>
#                  <a href="scene11f1.html">
#                   Squash - Winter
#                  </a>
#                  <br/>
#                  (Acorn, Butternut, others)
#                  <br/>
#                  <a href="scene6e2d.html">
#                   Swiss Chard
#                  </a>
#                  <br/>
#                  <a href="sceneea10.html">
#                   Tomatoes
#                  </a>
#                  <br/>
#                  <a href="scene0f7d.html">
#                   Turnips
#                  </a>
#                  <br/>
#                  <a href="scenea6a1.html">
#                   Vegetable Amaranth
#                  </a>
#                  <br/>
#                  <a href="scenedc02.html">
#                   Watermelon
#                  </a>
#                  <br/>
#                  <a href="scene6420.html">
#                   Zucchini
#                  </a>
#                 </div>
#                </td>
#               </tr>
#               <tr>
#                <td>
#                 <img alt="" height="30" src="img/dot_clear.gif" width="1"/>
#                </td>
#               </tr>
#              </table>
#             </td>
#            </tr>
#           </table>
#           <!-- END BODY INCLUDE for ALL TYPES -->
#           <!-- BEGIN NON-QTVR AND NON-IMG_V -->
#          </td>
#         </tr>
#         <tr>
#          <td valign="top">
#           <div class="description">
#           </div>
#           <div class="captionmuted">
#           </div>
#          </td>
#          <td>
#          </td>
#          <td>
#           <!-- background="/img/bg_dots.gif"]][[img src="/img/dot_clear.gif" alt="" width=1 height=1-->
#          </td>
#          <td>
#          </td>
#         </tr>
#         <!-- END NON-QTVR AND NON-IMG_V -->
#        </table>
#        <!-- ********************************************** END GALLERY TEMPLATE -->
#        <!-- ******************************************************************* -->
#        <!-- ******** end MAIN INCLUDE ******** -->
#       </td>
#      </tr>
#      <!-- begin column widths -->
#      <tr>
#       <td>
#        <img alt="" height="1" src="img/dot_clear.gif" width="460"/>
#       </td>
#       <td>
#        <img alt="" height="1" src="img/dot_clear.gif" width="19"/>
#       </td>
#       <td>
#        <img alt="" height="1" src="img/dot_clear.gif" width="1"/>
#       </td>
#       <td>
#        <img alt="" height="1" src="img/dot_clear.gif" width="30"/>
#       </td>
#       <td>
#        <img alt="" height="1" src="img/dot_clear.gif" width="210"/>
#       </td>
#      </tr>
#      <!-- end column widths -->
#     </table>
#     <!-- end UBER TABLE -->
#     <!-- ---------------------------- include footer -->
#     <table border="0" cellpadding="8" cellspacing="0" width="100%">
#      <tr bgcolor="e7e7dd">
#       <td>
#        <img border="0" height="1" src="img/dot_clear.gif" width="100"/>
#       </td>
#      </tr>
#      <tr>
#       <td align="middle" bgcolor="f5f5f2">
#        <table border="0" cellpadding="0" cellspacing="0" width="720">
#         <tr>
#          <td width="100%">
#           <div class="footer">
#            <p>
#             ©2006
#             <a href="http://www.cornell.edu">
#              Cornell University
#             </a>
#             . All rights reserved.
#            </p>
#           </div>
#          </td>
#         </tr>
#        </table>
#       </td>
#      </tr>
#     </table>
#     <!-- ---------------------------- include footer -->
#    </center>
#   </a>
#  </body>
#  <!-- Mirrored from explore.cornell.edu/scene.cfm?scene=home%20gardening&stop=HG%20%2D%20Find%20a%20Vegetable by HTTrack Website Copier/3.x [XR&CO'2006], Tue, 19 Sep 2006 18:40:15 GMT -->
# </html>

# %%
pages = []
for link in soup.find_all('a')[8:-1]:
    pages.append(str(link))
    print(link.get('href'))
# Out:
# scenec09b.html
# scene3693.html
# scenee3ed.html
# scenef57c.html
# scene8f63.html
# scene18f3.html
# scene0bdf.html
# scene91d8.html
# scenec40b.html
# scene2520.html
# scene5fdd.html
# scene5290.html
# scenea765.html
# scene595b.html
# scene810e.html
# sceneb528.html
# scene0072.html
# scene483b.html
# scene6f80.html
# scene05f6.html
# scene3673.html
# scenef65b.html
# scene98cf.html
# scene26b5.html
# scene18b1.html
# scenea2f3.html
# scene79ad.html
# scene568b.html
# scene57dc.html
# scene1357.html
# scene43f8.html
# scene9aa6.html
# scene144a.html
# scene46c5.html
# scene2b9a.html
# scene4983.html
# scene18b1.html
# scene80ea.html
# scene0bdf.html
# scenef2eb.html
# scene9697.html
# scene9c8a.html
# scenec6be.html
# scene61ea.html
# scene1f17.html
# scene341b.html
# scenec4d4.html
# scened5c9.html
# scene4983.html
# scene83de.html
# scene4c19.html
# scene9529.html
# scenef2e7.html
# scene6420.html
# scene11f1.html
# scene6e2d.html
# sceneea10.html
# scene0f7d.html
# scenea6a1.html
# scenedc02.html
# scene6420.html

# %%
pages
# Out:
# ['<a href="scenec09b.html">Artichoke - Globe</a>',
#  '<a href="scene3693.html">Arugula</a>',
#  '<a href="scenee3ed.html">Asparagus</a>',
#  '<a href="scenef57c.html">Beans - Bush</a>',
#  '<a href="scene8f63.html">Beans - Pole</a>',
#  '<a href="scene18f3.html">Beets</a>',
#  '<a href="scene0bdf.html">Bok Choy</a>',
#  '<a href="scene91d8.html">Broccoli</a>',
#  '<a href="scenec40b.html">Broccoli Raab</a>',
#  '<a href="scene2520.html">Brussels Sprouts</a>',
#  '<a href="scene5fdd.html">Cabbage - Common</a>',
#  '<a href="scene5290.html">Cabbage - Chinese</a>',
#  '<a href="scenea765.html">Carrots</a>',
#  '<a href="scene595b.html">Cauliflower</a>',
#  '<a href="scene810e.html">Celeriac</a>',
#  '<a href="sceneb528.html">Celery</a>',
#  '<a href="scene0072.html">Chives</a>',
#  '<a href="scene483b.html">Claytonia</a>',
#  '<a href="scene6f80.html">Collards</a>',
#  '<a href="scene05f6.html">Corn - Sweet</a>',
#  '<a href="scene3673.html">Cress - Garden</a>',
#  '<a href="scenef65b.html">Cucumbers</a>',
#  '<a href="scene98cf.html">Cutting Chicory</a>',
#  '<a href="scene26b5.html">Eggplant</a>',
#  '<a href="scene18b1.html">Egyptian Onion</a>',
#  '<a href="scenea2f3.html">Endive - Belgian</a>',
#  '<a href="scene79ad.html">Endive - Common</a>',
#  '<a href="scene568b.html">Garlic</a>',
#  '<a href="scene57dc.html">Kale</a>',
#  '<a href="scene1357.html">Kohlrabi</a>',
#  '<a href="scene43f8.html">Leeks</a>',
#  '<a href="scene9aa6.html">Lettuce</a>',
#  '<a href="scene144a.html">Melons</a>',
#  '<a href="scene46c5.html">Mizuna</a>',
#  '<a href="scene2b9a.html">Mustard Greens</a>',
#  '<a href="scene4983.html">Onions - Common</a>',
#  '<a href="scene18b1.html">Onions - Egyptian</a>',
#  '<a href="scene80ea.html">Orach</a>',
#  '<a href="scene0bdf.html">Pak Choy</a>',
#  '<a href="scenef2eb.html">Parsnips</a>',
#  '<a href="scene9697.html">Peas</a>',
#  '<a href="scene9c8a.html">Peppers</a>',
#  '<a href="scenec6be.html">Potatoes</a>',
#  '<a href="scene61ea.html">Pumpkins</a>',
#  '<a href="scene1f17.html">Radicchio</a>',
#  '<a href="scene341b.html">Radishes</a>',
#  '<a href="scenec4d4.html">Rhubarb</a>',
#  '<a href="scened5c9.html">Rutabagas</a>',
#  '<a href="scene4983.html">Scallions</a>',
#  '<a href="scene83de.html">Shallots</a>',
#  '<a href="scene4c19.html">Spinach - Common</a>',
#  '<a href="scene9529.html">Spinach - Malabar</a>',
#  '<a href="scenef2e7.html">Spinach - New Zealand</a>',
#  '<a href="scene6420.html">Squash - Summer</a>',
#  '<a href="scene11f1.html">Squash - Winter</a>',
#  '<a href="scene6e2d.html">Swiss Chard</a>',
#  '<a href="sceneea10.html">Tomatoes</a>',
#  '<a href="scene0f7d.html">Turnips</a>',
#  '<a href="scenea6a1.html">Vegetable Amaranth</a>',
#  '<a href="scenedc02.html">Watermelon</a>',
#  '<a href="scene6420.html">Zucchini</a>']

# %%
file = open("parsed_data.txt", "w")
for link in soup.find_all('a')[8:-1]:
    print(str(link))
    file.write(str(link))
file.flush()
file.close()
# Out:
# <a href="scenec09b.html">Artichoke - Globe</a>
# <a href="scene3693.html">Arugula</a>
# <a href="scenee3ed.html">Asparagus</a>
# <a href="scenef57c.html">Beans - Bush</a>
# <a href="scene8f63.html">Beans - Pole</a>
# <a href="scene18f3.html">Beets</a>
# <a href="scene0bdf.html">Bok Choy</a>
# <a href="scene91d8.html">Broccoli</a>
# <a href="scenec40b.html">Broccoli Raab</a>
# <a href="scene2520.html">Brussels Sprouts</a>
# <a href="scene5fdd.html">Cabbage - Common</a>
# <a href="scene5290.html">Cabbage - Chinese</a>
# <a href="scenea765.html">Carrots</a>
# <a href="scene595b.html">Cauliflower</a>
# <a href="scene810e.html">Celeriac</a>
# <a href="sceneb528.html">Celery</a>
# <a href="scene0072.html">Chives</a>
# <a href="scene483b.html">Claytonia</a>
# <a href="scene6f80.html">Collards</a>
# <a href="scene05f6.html">Corn - Sweet</a>
# <a href="scene3673.html">Cress - Garden</a>
# <a href="scenef65b.html">Cucumbers</a>
# <a href="scene98cf.html">Cutting Chicory</a>
# <a href="scene26b5.html">Eggplant</a>
# <a href="scene18b1.html">Egyptian Onion</a>
# <a href="scenea2f3.html">Endive - Belgian</a>
# <a href="scene79ad.html">Endive - Common</a>
# <a href="scene568b.html">Garlic</a>
# <a href="scene57dc.html">Kale</a>
# <a href="scene1357.html">Kohlrabi</a>
# <a href="scene43f8.html">Leeks</a>
# <a href="scene9aa6.html">Lettuce</a>
# <a href="scene144a.html">Melons</a>
# <a href="scene46c5.html">Mizuna</a>
# <a href="scene2b9a.html">Mustard Greens</a>
# <a href="scene4983.html">Onions - Common</a>
# <a href="scene18b1.html">Onions - Egyptian</a>
# <a href="scene80ea.html">Orach</a>
# <a href="scene0bdf.html">Pak Choy</a>
# <a href="scenef2eb.html">Parsnips</a>
# <a href="scene9697.html">Peas</a>
# <a href="scene9c8a.html">Peppers</a>
# <a href="scenec6be.html">Potatoes</a>
# <a href="scene61ea.html">Pumpkins</a>
# <a href="scene1f17.html">Radicchio</a>
# <a href="scene341b.html">Radishes</a>
# <a href="scenec4d4.html">Rhubarb</a>
# <a href="scened5c9.html">Rutabagas</a>
# <a href="scene4983.html">Scallions</a>
# <a href="scene83de.html">Shallots</a>
# <a href="scene4c19.html">Spinach - Common</a>
# <a href="scene9529.html">Spinach - Malabar</a>
# <a href="scenef2e7.html">Spinach - New Zealand</a>
# <a href="scene6420.html">Squash - Summer</a>
# <a href="scene11f1.html">Squash - Winter</a>
# <a href="scene6e2d.html">Swiss Chard</a>
# <a href="sceneea10.html">Tomatoes</a>
# <a href="scene0f7d.html">Turnips</a>
# <a href="scenea6a1.html">Vegetable Amaranth</a>
# <a href="scenedc02.html">Watermelon</a>
# <a href="scene6420.html">Zucchini</a>

# %%
s = pages[0]

start_scene = s.find("href") + len("href")+2
end_scene = s.find(".html")
substring_scene = s[start_scene:end_scene]

start_veggie = s.find(".html")+len(".html")+2
end_veggie = s.find('</a>')
substring_veggie = s[start_veggie:end_veggie]

pages_formated = "<a href=\""+substring_scene+".html\">"+substring_veggie+'</a>'
print(pages_formated)
# Out:
# <a href="scenec09b.html">Artichoke - Globe</a>

# %%
pages_formated = []
for page in pages:
    start_scene = page.find("href") + len("href")+2
    end_scene = page.find(".html")
    substring_scene = page[start_scene:end_scene]

    start_veggie = page.find(".html")+len(".html")+2
    end_veggie = page.find('</a>')
    substring_veggie = page[start_veggie:end_veggie]

    page_formated = "<a href=\""+substring_scene+".html\">"+substring_veggie+'</a>'
    pages_formated.append(page_formated)
print(pages_formated)
# Out:
# ['<a href="scenec09b.html">Artichoke - Globe</a>', '<a href="scene3693.html">Arugula</a>', '<a href="scenee3ed.html">Asparagus</a>', '<a href="scenef57c.html">Beans - Bush</a>', '<a href="scene8f63.html">Beans - Pole</a>', '<a href="scene18f3.html">Beets</a>', '<a href="scene0bdf.html">Bok Choy</a>', '<a href="scene91d8.html">Broccoli</a>', '<a href="scenec40b.html">Broccoli Raab</a>', '<a href="scene2520.html">Brussels Sprouts</a>', '<a href="scene5fdd.html">Cabbage - Common</a>', '<a href="scene5290.html">Cabbage - Chinese</a>', '<a href="scenea765.html">Carrots</a>', '<a href="scene595b.html">Cauliflower</a>', '<a href="scene810e.html">Celeriac</a>', '<a href="sceneb528.html">Celery</a>', '<a href="scene0072.html">Chives</a>', '<a href="scene483b.html">Claytonia</a>', '<a href="scene6f80.html">Collards</a>', '<a href="scene05f6.html">Corn - Sweet</a>', '<a href="scene3673.html">Cress - Garden</a>', '<a href="scenef65b.html">Cucumbers</a>', '<a href="scene98cf.html">Cutting Chicory</a>', '<a href="scene26b5.html">Eggplant</a>', '<a href="scene18b1.html">Egyptian Onion</a>', '<a href="scenea2f3.html">Endive - Belgian</a>', '<a href="scene79ad.html">Endive - Common</a>', '<a href="scene568b.html">Garlic</a>', '<a href="scene57dc.html">Kale</a>', '<a href="scene1357.html">Kohlrabi</a>', '<a href="scene43f8.html">Leeks</a>', '<a href="scene9aa6.html">Lettuce</a>', '<a href="scene144a.html">Melons</a>', '<a href="scene46c5.html">Mizuna</a>', '<a href="scene2b9a.html">Mustard Greens</a>', '<a href="scene4983.html">Onions - Common</a>', '<a href="scene18b1.html">Onions - Egyptian</a>', '<a href="scene80ea.html">Orach</a>', '<a href="scene0bdf.html">Pak Choy</a>', '<a href="scenef2eb.html">Parsnips</a>', '<a href="scene9697.html">Peas</a>', '<a href="scene9c8a.html">Peppers</a>', '<a href="scenec6be.html">Potatoes</a>', '<a href="scene61ea.html">Pumpkins</a>', '<a href="scene1f17.html">Radicchio</a>', '<a href="scene341b.html">Radishes</a>', '<a href="scenec4d4.html">Rhubarb</a>', '<a href="scened5c9.html">Rutabagas</a>', '<a href="scene4983.html">Scallions</a>', '<a href="scene83de.html">Shallots</a>', '<a href="scene4c19.html">Spinach - Common</a>', '<a href="scene9529.html">Spinach - Malabar</a>', '<a href="scenef2e7.html">Spinach - New Zealand</a>', '<a href="scene6420.html">Squash - Summer</a>', '<a href="scene11f1.html">Squash - Winter</a>', '<a href="scene6e2d.html">Swiss Chard</a>', '<a href="sceneea10.html">Tomatoes</a>', '<a href="scene0f7d.html">Turnips</a>', '<a href="scenea6a1.html">Vegetable Amaranth</a>', '<a href="scenedc02.html">Watermelon</a>', '<a href="scene6420.html">Zucchini</a>']

# %%
from parse import *

# %%
s = "<a href=\"scenec09b.html\">Artichoke - Globe</a>"

pattern =  "<a href=\"(.*?)\">(.*?)</a>"

scene = re.search(pattern, s).group(1)
vegetable = re.search(pattern, s).group(2)

print("Scene:"+scene+"\n","vegetable:"+vegetable)
# Out:
# Scene:scenec09b.html
#  vegetable:Artichoke - Globe

# %%
scenes = []
veggies = []
for page in pages_formated:
    
    pattern =  "<a href=\"(.*?)\">(.*?)</a>"

    scene = re.search(pattern, page).group(1)
    vegetable = re.search(pattern, page).group(2)
    scenes.append(scene)
    veggies.append(vegetable)
    print(" Scene:"+scene+"\n","Vegetable:"+vegetable+"\n")
# Out:
#  Scene:scenec09b.html
#  Vegetable:Artichoke - Globe
#
#  Scene:scene3693.html
#  Vegetable:Arugula
#
#  Scene:scenee3ed.html
#  Vegetable:Asparagus
#
#  Scene:scenef57c.html
#  Vegetable:Beans - Bush
#
#  Scene:scene8f63.html
#  Vegetable:Beans - Pole
#
#  Scene:scene18f3.html
#  Vegetable:Beets
#
#  Scene:scene0bdf.html
#  Vegetable:Bok Choy
#
#  Scene:scene91d8.html
#  Vegetable:Broccoli
#
#  Scene:scenec40b.html
#  Vegetable:Broccoli Raab
#
#  Scene:scene2520.html
#  Vegetable:Brussels Sprouts
#
#  Scene:scene5fdd.html
#  Vegetable:Cabbage - Common
#
#  Scene:scene5290.html
#  Vegetable:Cabbage - Chinese
#
#  Scene:scenea765.html
#  Vegetable:Carrots
#
#  Scene:scene595b.html
#  Vegetable:Cauliflower
#
#  Scene:scene810e.html
#  Vegetable:Celeriac
#
#  Scene:sceneb528.html
#  Vegetable:Celery
#
#  Scene:scene0072.html
#  Vegetable:Chives
#
#  Scene:scene483b.html
#  Vegetable:Claytonia
#
#  Scene:scene6f80.html
#  Vegetable:Collards
#
#  Scene:scene05f6.html
#  Vegetable:Corn - Sweet
#
#  Scene:scene3673.html
#  Vegetable:Cress - Garden
#
#  Scene:scenef65b.html
#  Vegetable:Cucumbers
#
#  Scene:scene98cf.html
#  Vegetable:Cutting Chicory
#
#  Scene:scene26b5.html
#  Vegetable:Eggplant
#
#  Scene:scene18b1.html
#  Vegetable:Egyptian Onion
#
#  Scene:scenea2f3.html
#  Vegetable:Endive - Belgian
#
#  Scene:scene79ad.html
#  Vegetable:Endive - Common
#
#  Scene:scene568b.html
#  Vegetable:Garlic
#
#  Scene:scene57dc.html
#  Vegetable:Kale
#
#  Scene:scene1357.html
#  Vegetable:Kohlrabi
#
#  Scene:scene43f8.html
#  Vegetable:Leeks
#
#  Scene:scene9aa6.html
#  Vegetable:Lettuce
#
#  Scene:scene144a.html
#  Vegetable:Melons
#
#  Scene:scene46c5.html
#  Vegetable:Mizuna
#
#  Scene:scene2b9a.html
#  Vegetable:Mustard Greens
#
#  Scene:scene4983.html
#  Vegetable:Onions - Common
#
#  Scene:scene18b1.html
#  Vegetable:Onions - Egyptian
#
#  Scene:scene80ea.html
#  Vegetable:Orach
#
#  Scene:scene0bdf.html
#  Vegetable:Pak Choy
#
#  Scene:scenef2eb.html
#  Vegetable:Parsnips
#
#  Scene:scene9697.html
#  Vegetable:Peas
#
#  Scene:scene9c8a.html
#  Vegetable:Peppers
#
#  Scene:scenec6be.html
#  Vegetable:Potatoes
#
#  Scene:scene61ea.html
#  Vegetable:Pumpkins
#
#  Scene:scene1f17.html
#  Vegetable:Radicchio
#
#  Scene:scene341b.html
#  Vegetable:Radishes
#
#  Scene:scenec4d4.html
#  Vegetable:Rhubarb
#
#  Scene:scened5c9.html
#  Vegetable:Rutabagas
#
#  Scene:scene4983.html
#  Vegetable:Scallions
#
#  Scene:scene83de.html
#  Vegetable:Shallots
#
#  Scene:scene4c19.html
#  Vegetable:Spinach - Common
#
#  Scene:scene9529.html
#  Vegetable:Spinach - Malabar
#
#  Scene:scenef2e7.html
#  Vegetable:Spinach - New Zealand
#
#  Scene:scene6420.html
#  Vegetable:Squash - Summer
#
#  Scene:scene11f1.html
#  Vegetable:Squash - Winter
#
#  Scene:scene6e2d.html
#  Vegetable:Swiss Chard
#
#  Scene:sceneea10.html
#  Vegetable:Tomatoes
#
#  Scene:scene0f7d.html
#  Vegetable:Turnips
#
#  Scene:scenea6a1.html
#  Vegetable:Vegetable Amaranth
#
#  Scene:scenedc02.html
#  Vegetable:Watermelon
#
#  Scene:scene6420.html
#  Vegetable:Zucchini

# %%
url_base = "http://www.gardening.cornell.edu/homegardening/"
url_scenes = []
for scene in scenes:
    url_scene = url_base+scene
    url_scenes.append(url_scene)
print(url_scenes)
# Out:
# ['http://www.gardening.cornell.edu/homegardening/scenec09b.html', 'http://www.gardening.cornell.edu/homegardening/scene3693.html', 'http://www.gardening.cornell.edu/homegardening/scenee3ed.html', 'http://www.gardening.cornell.edu/homegardening/scenef57c.html', 'http://www.gardening.cornell.edu/homegardening/scene8f63.html', 'http://www.gardening.cornell.edu/homegardening/scene18f3.html', 'http://www.gardening.cornell.edu/homegardening/scene0bdf.html', 'http://www.gardening.cornell.edu/homegardening/scene91d8.html', 'http://www.gardening.cornell.edu/homegardening/scenec40b.html', 'http://www.gardening.cornell.edu/homegardening/scene2520.html', 'http://www.gardening.cornell.edu/homegardening/scene5fdd.html', 'http://www.gardening.cornell.edu/homegardening/scene5290.html', 'http://www.gardening.cornell.edu/homegardening/scenea765.html', 'http://www.gardening.cornell.edu/homegardening/scene595b.html', 'http://www.gardening.cornell.edu/homegardening/scene810e.html', 'http://www.gardening.cornell.edu/homegardening/sceneb528.html', 'http://www.gardening.cornell.edu/homegardening/scene0072.html', 'http://www.gardening.cornell.edu/homegardening/scene483b.html', 'http://www.gardening.cornell.edu/homegardening/scene6f80.html', 'http://www.gardening.cornell.edu/homegardening/scene05f6.html', 'http://www.gardening.cornell.edu/homegardening/scene3673.html', 'http://www.gardening.cornell.edu/homegardening/scenef65b.html', 'http://www.gardening.cornell.edu/homegardening/scene98cf.html', 'http://www.gardening.cornell.edu/homegardening/scene26b5.html', 'http://www.gardening.cornell.edu/homegardening/scene18b1.html', 'http://www.gardening.cornell.edu/homegardening/scenea2f3.html', 'http://www.gardening.cornell.edu/homegardening/scene79ad.html', 'http://www.gardening.cornell.edu/homegardening/scene568b.html', 'http://www.gardening.cornell.edu/homegardening/scene57dc.html', 'http://www.gardening.cornell.edu/homegardening/scene1357.html', 'http://www.gardening.cornell.edu/homegardening/scene43f8.html', 'http://www.gardening.cornell.edu/homegardening/scene9aa6.html', 'http://www.gardening.cornell.edu/homegardening/scene144a.html', 'http://www.gardening.cornell.edu/homegardening/scene46c5.html', 'http://www.gardening.cornell.edu/homegardening/scene2b9a.html', 'http://www.gardening.cornell.edu/homegardening/scene4983.html', 'http://www.gardening.cornell.edu/homegardening/scene18b1.html', 'http://www.gardening.cornell.edu/homegardening/scene80ea.html', 'http://www.gardening.cornell.edu/homegardening/scene0bdf.html', 'http://www.gardening.cornell.edu/homegardening/scenef2eb.html', 'http://www.gardening.cornell.edu/homegardening/scene9697.html', 'http://www.gardening.cornell.edu/homegardening/scene9c8a.html', 'http://www.gardening.cornell.edu/homegardening/scenec6be.html', 'http://www.gardening.cornell.edu/homegardening/scene61ea.html', 'http://www.gardening.cornell.edu/homegardening/scene1f17.html', 'http://www.gardening.cornell.edu/homegardening/scene341b.html', 'http://www.gardening.cornell.edu/homegardening/scenec4d4.html', 'http://www.gardening.cornell.edu/homegardening/scened5c9.html', 'http://www.gardening.cornell.edu/homegardening/scene4983.html', 'http://www.gardening.cornell.edu/homegardening/scene83de.html', 'http://www.gardening.cornell.edu/homegardening/scene4c19.html', 'http://www.gardening.cornell.edu/homegardening/scene9529.html', 'http://www.gardening.cornell.edu/homegardening/scenef2e7.html', 'http://www.gardening.cornell.edu/homegardening/scene6420.html', 'http://www.gardening.cornell.edu/homegardening/scene11f1.html', 'http://www.gardening.cornell.edu/homegardening/scene6e2d.html', 'http://www.gardening.cornell.edu/homegardening/sceneea10.html', 'http://www.gardening.cornell.edu/homegardening/scene0f7d.html', 'http://www.gardening.cornell.edu/homegardening/scenea6a1.html', 'http://www.gardening.cornell.edu/homegardening/scenedc02.html', 'http://www.gardening.cornell.edu/homegardening/scene6420.html']

# %%
soups = []
for url in url_scenes:
    with urllib.request.urlopen(url) as response:
                            html = response.read()
    soup = BeautifulSoup(html,'lxml')
    soups.append(soup)

# %%
soup_example = soups[0]
#for linebreak in soup_example.find_all('br'):
    #linebreak.extract()
basic_info = soup_example.find("div", {"class": "normal"})

season = basic_info.find('p').get_text().strip()


scientific_name = basic_info.find('i').get_text()
#family = basic_info.find('i').next_sibling.next_sibling.strip()
pattern =  "(.*?) Family"
family = re.search(pattern, basic_info.get_text()).group(1)

description = basic_info.find_all('p')[2].get_text().strip()

print('Season: ',season)
print('Scientific_name: ', scientific_name)
print('Family: ', family)
print('Description:', description)
# Out:
# Season:  Vegetable (Cool Season) - Other
# Scientific_name:  Cynara scolymus
# Family:  Compositae
# Description: This cool-season perennial prized for its flavorful “hearts” is
# normally hardy to Zone 6 if well mulched, and occasionally Zone 5
# during mild winters. Its bristly leaves also add a unique texture to
# flower gardens.

# %%
veg_seasons = []
veg_scientific_names = []
veg_family = []
veg_description = []
for soup in soups:
    #for linebreak in soup_example.find_all('br'):
            #linebreak.extract()
    basic_info = soup.find("div", {"class": "normal"})

    season = basic_info.find('p').get_text().strip()

    scientific_name = basic_info.find('i').get_text().strip()

    #between_breaks = basic_info.find('p').next_sibling.next_element.get_text().strip().split('\n\r\n\r\n\r\n\r\n')
    #scientific_name = between_breaks[0]
    #family = between_breaks[1]
    #family = basic_info.find('i').next_sibling.next_element.strip()
    pattern =  "(.*?) Family"
    family = re.search(pattern, basic_info.get_text()).group(1)


    description = basic_info.find_all('p')[2].get_text().strip()
    veg_seasons.append(season)
    veg_scientific_names.append(scientific_name)
    veg_family.append(family)
    veg_description.append(description)
    print('Season: ',season)
    print('Scientific_name: ', scientific_name)
    print('Family: ', family)
    print('Description:', description)
    print('')
# Out:
# Season:  Vegetable (Cool Season) - Other
# Scientific_name:  Cynara scolymus
# Family:  Compositae
# Description: This cool-season perennial prized for its flavorful “hearts” is
# normally hardy to Zone 6 if well mulched, and occasionally Zone 5
# during mild winters. Its bristly leaves also add a unique texture to
# flower gardens.
#
# Season:  Vegetable (Cool Season) - Salad Greens
# Scientific_name:  Eruca vesicaria
# Family:  Brassicaceae
# Description: This fast-growing cool-season salad green - often ready to harvest as
# early as 4 weeks after seeding - adds a tangy, peppery or mustard-like
# flavor to salads and mesclun mixes.
#
# Season:  Vegetable (Cool Season) - Other
# Scientific_name:  Asparagus officianalis
# Family:  Liliaceae
# Description: Among the earliest crops in spring, plantings of this hardy perennial
# can last for decades if well cared for, and the fine foliage makes it a
# natural for edible landscaping. The tender spears are tastiest when
# eaten as soon as possible after harvest.
#
# Season:  Vegetable (Warm Season) - Other
# Scientific_name:  Phaseolus vulgaris (Bush beans)
# Family:  Fabaceae
# Description: You can harvest this staple of the vegetable garden as snap beans,
# shell beans or dry beans. They are extremely easy to grow, but if your
# garden is small, consider planting pole beans. They yield two to three
# times more from the same space.
#
# Season:  Vegetable (Warm Season) - Other
# Scientific_name:  Phaseolus vulgaris (Pole beans)
# Family:  Fabaceae
# Description: Note: There are other species of beans with climbing growth habit, such as  Phaseolus lunatus (butterbean) Phaseolus coccineus (scarlet runner bean), Psophocrapus tetragonolobus (winged bean), Vigna unguiculata (yard-long bean), etc.
#
# Season:  Vegetable (Cool Season) - Spinach, Beets, Chard,
#
#
#
#
#
#
#
#
#
#
#
# Vegetable (Warm Season) - Salad Greens
# Scientific_name:  Beta vulgaris subsp. vulgaris
# Family:  Chenopodiaceae
# Description: Easy-to-grow beets do double-duty in the kitchen, producing tasty roots
# for baking, boiling or sautéing and fresh greens to boil or steam.
# Plant them early for top quality and best flavor. (Fluctuating weather
# can reduce quality and create white zone rings in the roots.) Some
# varieties have red stems and venation in the leaves, making them a
# natural for edible landscaping.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica rapa var. chinensis
# Family:  Vegetable (Cool Season) - Cabbage
# Description: No matter how you spell it, pak choy’s mild flavor is a must for stir
# fries. It’s not as finicky about heat and cold as Chinese cabbage, and
# the striking white petioles and green leaves make it a must for edible
# landscaping.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica oleracea var. botrytis (Broccoli)
# Family:  Vegetable (Cool Season) - Cabbage
# Description: This cool-season crop grows best when daytime temperatures are in the
# 60s F. Grow in both spring and fall, but avoid mid-summer crops as hot
# weather can cause premature bolting. Romanesco types are especially
# handsome choices for edible landscaping.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica ruvo
# Family:  Vegetable (Cool Season) - Cabbage
# Description: An Italian favorite with a somewhat bitter taste, this fast-growing,
# cool-season annual forms loose flower heads similar to broccoli in the
# axils of lower leaves.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica oleracea var. gemmifera
# Family:  Vegetable (Cool Season) - Cabbage
# Description: This cool-season crop is most flavorful after it is “kissed” by frost.
# Keep plantings moist and well-mulched during the heat of summer, and
# you will be rewarded with sprouts until Christmas or beyond.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica oleracea var. capitata
# Family:  Vegetable (Cool Season) - Cabbage
# Description: This cool-season crop grows best when daytime temperatures are in the
# 60s F. Direct-seed or transplant spring crops for fresh use in summer.
# Plant fall crops for winter storage or sauerkraut.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica rapa  var. pekinensis
# Family:  Vegetable (Cool Season) - Cabbage
# Description: This cool-season crop combines the flavor of cabbage and the texture of
# romaine lettuce, but exposing young plants to frost or prolonged
# temperatures below 50 F may cause them to bolt prematurely. Fall crops
# are more reliable.
#
# Season:  Vegetable (Cool Season) - Parsley Family
# Scientific_name:  Daucus carota var. sativus
# Family:  Vegetable (Cool Season) - Parsley
# Description: Careful attention to the soil makes these Vitamin A-rich roots a snap
# to grow. Plant in deep, stone-free soil (a raised bed is great) with a
# fine surface. Thin and weed carefully, and mulch to keep soil cool.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica oleracea var. botrytis (Cauliflower)
# Family:  Vegetable (Cool Season) - Cabbage
# Description: The most finicky and difficult of the cole (cabbage family) crops to
# grow, cauliflower flourishes when temperatures are moderate. Purple
# (left), orange and yellow-green colored varieties make good addition to
# flower gardens.
#
# Season:  Vegetable (Cool Season) - Parsley Family
# Scientific_name:  Apium graveolens  var. Rapaceum
# Family:  Vegetable (Cool Season) - Parsley
# Description: Celeriac is closely related to celery, but easier to grow. It is prized
# for its crisp, celery-flavored root, which you can eat raw or cooked. A
# staple in Europe, it is little known in North America.
#
# Season:  Vegetable (Cool Season) - Parsley Family
# Scientific_name:  Apium graveolens  var. dulce
# Family:  Vegetable (Cool Season) - Parsley
# Description: Perhaps the most difficult vegetable to grow in many areas, this
# long-season crop must be started inside. Seeds are slow to germinate,
# and if transplanted outside too early, plants will bolt in response to
# cold. Also requires consistent moisture and dislikes heat.
#
# Season:  Herbaceous Perennial Flower,
#
#
#
#
#
#
#
#
#
#
#
# Herb,
#
#
#
#
#
#
#
#
#
#
#
# Vegetable (Cool Season) - Onion Family
# Scientific_name:  Allium schoenoprasum
# Family:  Vegetable (Cool Season) - Onion
# Description: Great for dressing up potatoes and spicing up salads, this easy-to-grow
# Allium’s pinkish-lavender flowers make an attractive clump or edging in
# flower gardens.
#
# Season:  Vegetable (Cool Season) - Salad Greens
# Scientific_name:  Claytonia perfoliata
# Family:  Portulacaceae
# Description: This cool-season salad green readily self-seeds and can overwinter in
# Zone 6 and warmer. While somewhat aggressive, it makes a handsome
# low-growing cover for edible landscaping.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica oleracea var. acephala (collards)
# Family:  Vegetable (Cool Season) - Cabbage
# Description: The flavor of this traditional Southern potherb is improved by frost.
# Very cold hardy (harvest can continue right through snow), collards are
# also among the most heat tolerant of cole crops.
#
# Season:  Vegetable (Warm Season) - Other
# Scientific_name:  Zea mays
# Family:  Gramineae
# Description: Corn demands fertile soil, consistent moisture and warm weather. If you
# have those and plenty of garden space to spare, it’s not hard to grow
# great-tasting corn, and you won’t get it any fresher.
#
# Season:  Vegetable (Cool Season) - Salad Greens
# Scientific_name:  Lepidium sativum
# Family:  Brassicaceae
# Description: The easiest of the cresses to grow, garden cress can be harvested in as
# little as two weeks after sowing. It’s peppery taste adds zing to
# salads, but hot weather makes this cool-season crop bitter and
# inedible.
#
# Season:  Vine,
#
#
#
#
#
#
#
#
#
#
#
# Vegetable (Warm Season) - Cucurbit
# Scientific_name:  Cucumis sativus
# Family:  Cucurbitaceae
# Description: Whether for pickling or slicing, cucumbers are easy to grow if you give
# them good soil, full sun and sufficient moisture, and wait for weather
# to warm before planting.
#
# Season:  Vegetable (Cool Season) - Salad Greens,
#
#
#
#
#
#
#
#
#
#
#
# Vegetable (Warm Season) - Salad Greens
# Scientific_name:  Cichorium intybus (Cutting chicory)
# Family:  Compositae
# Description: This bitter Italian green grows quickly, with immature leaves ready to
# harvest in just 3 to 5 weeks. Prefers cool weather but will produce
# greens throughout the season.
#
# Season:  Vegetable (Warm Season) - Tomatoes, Peppers, Eggplant
# Scientific_name:  Solanum melongena
# Family:  Solanaceae
# Description: Dramatic foliage and colorful fruits (white, green and other colors in
# addition to the usual deep purple) make this heat-loving annual a good
# choice for ornamental beds as well as vegetable gardens. Needs two or
# more months with night-time temperatures near 70 F for good fruit
# production. Test.
#
# Season:  Vegetable (Cool Season) - Onion Family
# Scientific_name:  Allium cepa var. proliferum
# Family:  Vegetable (Cool Season) - Onion
# Description: Similar to shallots - but with a much stronger flavor - this perennial
# allium produces numerous bulbs below ground, and as a bonus forms
# clusters of sets for replanting on its stalk.
#
# Season:  Vegetable (Cool Season) - Salad Greens
# Scientific_name:  Cichorium intybus (Belgian endive)
# Family:  Compositae
# Description: Grow the roots like carrots during summer. (They can be ground for a
# coffee substitute.) Harvest and store for forcing gourmet “chicons” - 4
# to 6-inch spindle-shaped heads or buds -- for winter salads.
#
# Season:  Vegetable (Cool Season) - Salad Greens
# Scientific_name:  Cichorium endiva (Endive)
# Family:  Compositae
# Description: Flat-leaved varieties are known as escarole, these cool-season greens
# are known for their sharp, bitter taste. More tolerant of heat and cold
# than lettuce, frilly-leaved endive makes an attractive addition to
# ornamental plantings.
#
# Season:  Vegetable (Cool Season) - Onion Family
# Scientific_name:  Allium sativum var. sativum and ophiosco
# Family:  Vegetable (Cool Season) - Onion
# Description: Easy to grow and productive - a pound of cloves can produce 7 to 10
# pounds of garlic - the “stinking rose” needs rich, well-drained soil,
# full sun and excellent weed control.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica oleracea var. acephala (Kale)
# Family:  Vegetable (Cool Season) - Cabbage
# Description: The tender young leaves from these fast-growing plants can be eaten
# raw, or cooked for soup or stir fries. Very cold hardy, harvest can
# continue right through snow. Many colored varieties are a fine addition
# to ornamental plantings as well as spectacular garnishes.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica oleracea var. gongylodes
# Family:  Vegetable (Cool Season) - Cabbage
# Description: This cool-season cole crop produces a turnip-flavored swollen stem in
# as little as 6 weeks. In addition to spring crops, you can tuck in
# transplants or sow seeds anywhere space becomes available in summer.
# The bizarre alien-from-outer-space appearance makes it an eye-stopper
# in ornamental plantings, too.
#
# Season:  Vegetable (Cool Season) - Onion Family
# Scientific_name:  Allium ampeloprasum
# Family:  Vegetable (Cool Season) - Onion
# Description: Milder flavored than most other onion-family crops, you can mulch long-season varieties in fall for winter and spring harvest.
#
# Season:  Vegetable (Cool Season) - Salad Greens
# Scientific_name:  Lactuca sativa
# Family:  Asteraceae
# Description: With the variety of colors, shapes and flavors available, your salads
# may never be the same. Lettuce is adapatable to many growing
# conditions, but likes it cool - around 60 F to 65 F. Grow in spring and
# fall, and slow bolting by shading summer crops.
#
# Season:  Vegetable (Warm Season) - Cucurbit
# Scientific_name:  Cucumis melo
# Family:  Cucurbitaceae
# Description: Heat-loving melons can be a challenge to grow in cooler regions of New
# York. To increase success, choose short-season varieties, start them
# inside, warm soil with black plastic or IRT mulch, and protect young
# plants with fabric row covers.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica rapa var. Japonica
# Family:  Vegetable (Cool Season) - Cabbage
# Description: This Asian green is prized for its mild flavor in salads and stir
# fries, heat- and cold-tolerance, and fine leaves that form an
# attractive rosette.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica juncea
# Family:  Vegetable (Cool Season) - Cabbage
# Description: This cool-season green adds a peppery zing to salads, and makes an
# attractive addition to ornamental plantings. When plants bolt, harvest
# flowers and seedpods for salads, too.
#
# Season:  Vegetable (Cool Season) - Onion Family
# Scientific_name:  Allium cepa var. cepa
# Family:  Vegetable (Cool Season) - Onion
# Description: Whether harvested early for scallions (green onions), for summer meals,
# or winter storage, onions need rich, well-drained soil and good weed
# control. Tightly spaced green onions fit well in ornamental plantings.
#
# Season:  Vegetable (Cool Season) - Onion Family
# Scientific_name:  Allium cepa var. proliferum
# Family:  Vegetable (Cool Season) - Onion
# Description: Similar to shallots - but with a much stronger flavor - this perennial
# allium produces numerous bulbs below ground, and as a bonus forms
# clusters of sets for replanting on its stalk.
#
# Season:  Vegetable (Cool Season) - Salad Greens,
#
#
#
#
#
#
#
#
#
#
#
# Vegetable (Warm Season) - Salad Greens
# Scientific_name:  Atriplex hortensis
# Family:  Chenopodiaceae
# Description: Touted as a warm-season alternative to spinach, orach is actually a
# cool-season plant that just doesn’t go to seed (bolt) as quickly as
# spinach. Harvest leaves that are less-bitter than spinach into the
# summer. Red varieties in particular make good ornamental plants, though
# can reach 4 to 6 feet tall.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica rapa var. chinensis
# Family:  Vegetable (Cool Season) - Cabbage
# Description: No matter how you spell it, pak choy’s mild flavor is a must for stir
# fries. It’s not as finicky about heat and cold as Chinese cabbage, and
# the striking white petioles and green leaves make it a must for edible
# landscaping.
#
# Season:  Vegetable (Cool Season) - Parsley Family
# Scientific_name:  Pastinaca sativa
# Family:  Vegetable (Cool Season) - Parsley
# Description: Perhaps the hardiest of all garden crops, parsnips don’t develop their
# sweet, nutty flavor until after enduring frosts and cold weather in
# fall. Can be overwintered for harvest as soon as soil thaws in spring.
#
# Season:  Vegetable (Warm Season) - Other
# Scientific_name:  Pisum sativum
# Family:  Leguminosae
# Description: Like sweet corn, peas are at their tastiest immediately after harvest.
# Whether you choose shell or edible-pod peas, they grow best during
# spring and early summer when temperatures are between 60 F to 75 F.
#
# Season:  Vegetable (Warm Season) - Tomatoes, Peppers, Eggplant
# Scientific_name:  Capsicum annuum (culinary)
# Family:  Solanaceae
# Description: Sometimes peppers are a challenge to grow in cooler areas of New York.
# The many varieties of sweet and hot peppers thrive on full sun, warm
# weather, well-drained soil and modest fertility.
#
# Season:  Vegetable (Warm Season) - Other,
#
#
#
#
#
#
#
#
#
#
#
# Root Crop
# Scientific_name:  Solanum tuberosum
# Family:  Solanaceae
# Description: A nutritional mother lode, potatoes are easy to grow as long as they
# have full sun, moderate temperatures, and light, rich, acidic,
# well-drained soil. Try varieties with colors, shapes and flavors you
# won't find in the supermarket.
#
# Season:  Vegetable (Warm Season) - Cucurbit
# Scientific_name:  Cucurbita maxima, C. pepo, C. moschata, C. argyrosperma
# Family:  Cucurbitaceae
# Description: With fertile soil and a long enough growing season, it's easy to grow
# your own Jack-o-lanterns -- if you have enough space. Choose varieties
# bred for flavor if you want to make pies.
#
# Season:  Vegetable (Cool Season) - Salad Greens
# Scientific_name:  Cichorium intybus
# Family:  Compositae
# Description: The small red and white heads of this chicory family member form best
# in cool weather. It is a staple in Italian salads with its bright color
# and bitter - but not overpowering - flavor.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Raphanus sativus
# Family:  Vegetable (Cool Season) - Cabbage
# Description: Easy to grow and ready to harvest in just 3 to 6 weeks. Make plantings
# of cool-season spring radishes every week or two for a continuous
# harvest until hot weather hits. Don’t forget winter varieties that
# produce large, fall-harvested roots.
#
# Season:  Vegetable (Cool Season) - Other
# Scientific_name:  Rheum x cultorum
# Family:  Polygonaceae
# Description: This tart, easy-to-grow perennial is great for pies and jams,
# especially when coupled with strawberries. It comes to life when
# temperatures rise into the 40s F, making it one of the earliest spring
# crops.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica napus var. napobrassica
# Family:  Vegetable (Cool Season) - Cabbage
# Description: Easy-to-grow softball-sized root crop is a favorite for fall and winter
# soups and dishes, and can also be used raw in salads. Rutabagas are
# often confused with turnips, but are sweeter flavored.
#
# Season:  Vegetable (Cool Season) - Onion Family
# Scientific_name:  Allium cepa var. cepa
# Family:  Vegetable (Cool Season) - Onion
# Description: Whether harvested early for scallions (green onions), for summer meals,
# or winter storage, onions need rich, well-drained soil and good weed
# control. Tightly spaced green onions fit well in ornamental plantings.
#
# Season:  Vegetable (Cool Season) - Onion Family
# Scientific_name:  Allium cepa  var. aggregatum
# Family:  Vegetable (Cool Season) - Onion
# Description: An easy-to-grow gourmet favorite, these perennial onions produce a
# cluster of smaller bulbs instead of one large bulb. You can replant
# small bulbs for next year’s crop.
#
# Season:  Vegetable (Cool Season) - Salad Greens,
#
#
#
#
#
#
#
#
#
#
#
# Vegetable (Cool Season) - Spinach, Beets, Chard
# Scientific_name:  Spinacia oleracea
# Family:  Chenopodiaceae
# Description: This easy-to-grow, nutritious, cool-season crop is among the first
# greens ready to harvest. But plant it early because it’s quick to turn
# bitter and go to seed (bolt) as the weather warms and the days
# lengthen. Dark green color and handsome texture of savoyed varieties
# are great for edible landscaping.
#
# Season:  Vine,
#
#
#
#
#
#
#
#
#
#
#
# Vegetable (Warm Season) - Salad Greens
# Scientific_name:  Basella alba
# Family:  Basellaceae
# Description: The leaves from this heat-loving vine have a mild flavor and are used
# like spinach in salads and cooking. Extremely frost-sensitive. It
# creeps when temperatures are cool, but leaps when the mercury hits 90
# F.
#
# Season:  Vegetable (Warm Season) - Salad Greens
# Scientific_name:  Tetragonia tetragonoides
# Family:  Aizoaceae
# Description: Used like spinach in cooking and salads, this frost-tender plant is
# ready for harvest when spinach is on the wane, and stays productive
# throughout summer. Also makes an attractive foliage plant for borders
# and beds.
#
# Season:  Vegetable (Warm Season) - Cucurbit
# Scientific_name:  Cucurbita pepo
# Family:  Cucurbitaceae
# Description: Summer squash comes in a variety of shapes and colors. Bush varieties
# take up relatively little space, and if kept picked will keep producing
# right up to frost.
#
# Season:  Vegetable (Warm Season) - Cucurbit
# Scientific_name:  Cucurbita maxima, C. pepo, C. moschata
# Family:  Cucurbitaceae
# Description: Winter squash are easy to grow -- if you have room. In addition to the
# familiar butternut and acorn squash, varieties come in a staggering
# diversity of fruit size, shape and color. Choose bush varieties if
# space is tight.
#
# Season:  Vegetable (Cool Season) - Spinach, Beets, Chard,
#
#
#
#
#
#
#
#
#
#
#
# Vegetable (Warm Season) - Salad Greens
# Scientific_name:  Beta vulgaris subsp. cicla
# Family:  Chenopodiaceae
# Description: Grown for its tasty and nutritious leaves and leafstalks (petioles),
# chard is a good substitute for spinach in most recipes. Prefers cool
# weather, but lasts through summer without going to seed (bolting).
# Colorful leaves and petioles make it great for edible landscaping and
# ornamental plantings.
#
# Season:  Vegetable (Warm Season) - Tomatoes, Peppers, Eggplant
# Scientific_name:  Lycopersicon esculentum
# Family:  Solanaceae
# Description: The most popular garden vegetable crop, tomatoes come in a wide range
# of sizes, shapes and colors. Choose determinate varieties for early
# harvest or cool conditions. Compact varieties are also good choices for
# containers and planting in flower beds.
#
# Season:  Vegetable (Cool Season) - Cabbage Family
# Scientific_name:  Brassica rapa var. rapa
# Family:  Vegetable (Cool Season) - Cabbage
# Description: Fast-growing spring turnip crops are best harvested while the weather
# is still cool. The flavor of fall crops is improved by light frost.
# Don’t forget the greens which are delightful raw or cooked.
#
# Season:  Vegetable (Warm Season) - Salad Greens
# Scientific_name:  Amaranthus tricolor
# Family:  Amaranthaceae
# Description: This warm-season salad green can help fill the gap between spring and
# fall harvest of cool-season greens. You can also cook it like spinach
# or use it in stir fries. Use variegated varieties as ornamentals.
#
# Season:  Vegetable (Warm Season) - Cucurbit
# Scientific_name:  Citrullus lanatus
# Family:  Cucurbitaceae
# Description: Heat-loving watermelons can be a challenge to grow in cooler regions of
# New York. To increase success, choose short-season varieties, start
# them inside, warm soil with black plastic or IRT mulch, and protect
# young plants with fabric row covers.
#
# Season:  Vegetable (Warm Season) - Cucurbit
# Scientific_name:  Cucurbita pepo
# Family:  Cucurbitaceae
# Description: Summer squash comes in a variety of shapes and colors. Bush varieties
# take up relatively little space, and if kept picked will keep producing
# right up to frost.

# %%
soup_example = soups[40]

if soup_example.find(text="Sunlight:") != None:
    sunlight = soup_example.find(text="Sunlight:").next_element.next_element.get_text().strip()
    print("sunlight: ",example)
    
if soup_example.find(text="Soil conditions:") != None:
    soil_condition = soup_example.find(text="Soil conditions:").next_element.next_element.next_element.get_text().strip()
    print("Soil conditions: ",soil_condition)
    
if soup_example.find(text="Hardiness zones:")!= None:
    hardiness = soup_example.find(text="Hardiness zones:").next_element.next_element.next_element.get_text().strip()
    print("Hardiness zones: ",hardiness)
    
if soup_example.find(text="Lifecycle:") != None:
    lifecycle = soup_example.find(text="Lifecycle:").next_element.strip()
    print("Lifecycle: ",lifecycle)
    
if soup_example.find(text="Ease-of-care:") != None:
    ease_of_care = soup_example.find(text="Ease-of-care:").next_element.strip()
    print("Ease-of-care: ",ease_of_care)

if soup_example.find(text="Foliage color:") != None:
    Foliage_color = soup_example.find(text="Foliage color:").next_element.strip()
    print("Foliage color:",Foliage_color)
    
if soup_example.find(text="Foliage texture:") != None:
    Foliage_texture = soup_example.find(text="Foliage texture:").next_element.strip()
    print("Foliage texture:",Foliage_texture)

#if soup_example.find(text="Shape:")!= None:
 #   shape = soup_example.find(text="Shape:").next_element.next_element.next_element.next_element.next_element.strip()
  #  shape = soup_example.find(text="Shape:").next_element.next_element.get_text()
   # print("Shape: ",shape)

if soup_example.find(text="Tolerates:") != None:
    tolerates = soup_example.find(text="Tolerates:").next_element.next_element.get_text().strip()
    print("Tolerates: ",tolerates)

if soup_example.find(text="Special characteristics:") != None:
    special_charac = soup_example.find(text="Special characteristics:").next_element.next_element.get_text().strip()
    print("Special characteristics: ",special_charac)
# Out:
# sunlight:
# full sun
#
# Soil conditions:  requires well-drained soil
# Lifecycle:  annual
# Ease-of-care:  easy
# Foliage color:
# Foliage texture: fine
# Tolerates:  frost - Can tolerate moderate freezes. Less sensitive to freezing in
# spring than in fall. Light damage to shoots can actually encourage more
# secondary shoots and result in more pods per plant.
# Special characteristics:  not native to North America
#
#
#
# 	 - Domesticated by Neolithic farmers in the Near East at least 8,000 to 9,000 years ago.

# %%
sunlight_all = []
soil_condition_all = []
hardiness_all = []
lifecycle_all = []
ease_care = []
foliage_color_all = []
foliage_texture_all = []
tolerates_all = []
special_charac_all = []
for soup in soups:
    if soup.find(text="Sunlight:") != None:
        sunlight = soup.find(text="Sunlight:").next_element.next_element.get_text().strip()
        sunlight_all.append(sunlight)
    else:
        sunlight_all.append(None)
    
    if soup.find(text="Soil conditions:") != None:
        soil_condition = soup.find(text="Soil conditions:").next_element.next_element.next_element.get_text().strip()
        soil_condition_all.append(soil_condition)
    else:
        soil_condition_all.append(None)
    
    if soup.find(text="Hardiness zones:")!= None:
        hardiness = soup.find(text="Hardiness zones:").next_element.next_element.next_element.get_text().strip()
        hardiness_all.append(hardiness)
    else:
        hardiness_all.append(None)
    
    if soup.find(text="Lifecycle:") != None:
        lifecycle = soup.find(text="Lifecycle:").next_element.strip()
        lifecycle_all.append(lifecycle)
    else:
        lifecycle_all.append(None)
    
    if soup.find(text="Ease-of-care:") != None:
        ease_of_care = soup.find(text="Ease-of-care:").next_element.strip()
        ease_care.append(ease_of_care)
    else:
        ease_care.append(None)

    if soup.find(text="Foliage color:") != None:
        foliage_color = soup.find(text="Foliage color:").next_element.strip()
        foliage_color_all.append(foliage_color)
    else:
        foliage_color_all.append(None)

    if soup.find(text="Foliage texture:") != None:
        foliage_texture = soup.find(text="Foliage texture:").next_element.strip()
        foliage_texture_all.append(foliage_texture)
    else:
        foliage_texture_all.append(None)

    if soup.find(text="Tolerates:") != None:
        tolerates = soup.find(text="Tolerates:").next_element.next_element.get_text().strip()
        tolerates_all.append(tolerates)
    else:
        tolerates_all.append(None)
        
    if soup.find(text="Special characteristics:") != None:
        special_charac = soup.find(text="Special characteristics:").next_element.next_element.get_text().strip()
        special_charac_all.append(special_charac.replace('\r','').replace('\n','').replace('\t',''))
    else:
        special_charac_all.append(None)

# %%
#Growing Information
soup_example = soups[9]

#if soup_example.find(text="How to plant:") != None:
 #   sunlight = soup_example.find(text="Sunlight:").next_element.next_element.get_text().strip()
  #  print("sunlight: ",example)
item = soup_example.find(text="How to plant:").next_element.next_element.get_text().strip().replace('\t','').replace('\r','').split('\n')
while("" in item) : 
    item.remove("")
listToStr = ' '.join([str(element) for element in item]) 
print(listToStr)
# Out:
# Propagate by   seed   Germination temperature: 45 F to 85 F  - Will germinate at soil temperatures as low as 40 F. Days to emergence: 5 to 8

# %%
listToStr = listToStr.replace('Germination temperature', '').replace('Days to emergence','')
grow_info=re.split('[:]',listToStr)
print('How to grow:',grow_info[0])
print('Germination Temperature:',grow_info[1])
print('Days to Emergence',grow_info[2])

piece_start = grow_info[2].find('Seed can be saved')
piece = grow_info[2]
print(piece[:piece_start])
print(piece[piece_start:])
print(piece_start)
# Out:
# How to grow: Propagate by   seed
# Germination Temperature:  45 F to 85 F  - Will germinate at soil temperatures as low as 40 F.
# Days to Emergence  5 to 8
#  5 to
# 8
# -1

# %%
how_to_grow = []
germination_temp = []
emergence_days = []
seed_save = []

for soup in soups:
    item = soup.find(text="How to plant:").next_element.next_element.get_text().strip().replace('\t','').replace('\r','').split('\n')
    while("" in item) : 
        item.remove("")
    listToStr = ' '.join([str(element) for element in item]) 
    listToStr = listToStr.replace('Germination temperature', '').replace('Days to emergence','')
    grow_info=re.split('[:]',listToStr)
    how_to_grow.append(grow_info[0].replace('  ',''))
    #fix comparison
    if (len(grow_info) > 1):
        germination_temp.append(grow_info[1])
    else:
        germination_temp.append('')
    if (len(grow_info)>2):
        piece = grow_info[2]
        piece_start = piece.find('Seed can be saved')
        if (piece_start)!= -1:
            emergence_days.append(piece[:piece_start])
            seed_save.append(piece[piece_start:])
        else:
            emergence_days.append(piece)
            seed_save.append('')
    else:
        emergence_days.append('')
        seed_save.append('')

# %%
#Maintenace Information
soup_example = soups[0]

element = soup_example.find(text="Maintenance and care:").next_element.next_element.get_text().strip().replace('\r','').replace('\n','')
print(element)
# Out:
# Plant root divisions (basal stem pieces with attached roots) after last frost, 2 to 3 feet apart in rows 2.5 to 3 feet apart.Plantingfrom seed not recommended because results are highly variable andusually inferior to parent plants. But if you do, start seeds about 8to 12 weeks before last frost. Harden off in cold frame. Cold treatmentof starts (keeping temperature between 35 F and 50 F for about 10 days)can induce flowering in first-year plants. Transplant outside aftersoil has reached 60 F.Benefits from the use of a low-nitrogenfertilizer (high in phosphorus and potassium), which can beincorporated before planting. Plants usually don’t flower the first year.Toincrease chance of overwintering, head back to 12 inches and cover withleaves, covered with baskets or boxes, and heap more leaves over thetop of the basket. Another alternative is to dig roots and store in acold (but not freezing) room. Pot up about a month before transplantingout after last frost.While individual plants may live up to 15 years or more, divide about every 3 years to keep planting productive.

# %%
#Pest Info
soup_example = soups[0]
element = soup_example.find(text="Pests:").next_element.next_element.get_text().replace('\r','').replace('\n','')

# %%
pests_info = []
maintenance_info = []
for soup in soups:
    if soup.find(text="Maintenance and care:") != None:
        maintenance = soup.find(text="Maintenance and care:").next_element.next_element.get_text().strip().replace('\r','').replace('\n','')
        maintenance_info.append(maintenance)
    else:
        maintenance_info.append('')
    if soup.find(text="Pests:") != None:
        pests = soup.find(text="Pests:").next_element.next_element.get_text().replace('\r','').replace('\n','').replace('\t','')
        pests_info.append(pests)
    else:
        pests_info.append('')

# %%
import pandas as pd

# %%
d = {'veggie': veggies,'scene':scenes,'url_scene':url_scenes,'season':veg_seasons,'scientific_name':veg_scientific_names,'family':veg_family,'description': veg_description, 'sunlight':sunlight_all,'soil conditions':soil_condition_all,'hardiness':hardiness_all,'lifecycle':lifecycle_all,'ease of care':ease_care,'foliage colors':foliage_color_all,'foliage texture':foliage_texture_all,'tolerates':tolerates_all,'special characteristics':special_charac_all,'how to grow':how_to_grow,'germination temperature':germination_temp,'emergence days':emergence_days,'seed save time':seed_save,'Maintenance Info':maintenance_info,'Pests':pests_info}
df = pd.DataFrame(data=d)

# %%
df
# Out:
#                 veggie           scene  \
# 0    Artichoke - Globe  scenec09b.html
# 1              Arugula  scene3693.html
# 2            Asparagus  scenee3ed.html
# 3         Beans - Bush  scenef57c.html
# 4         Beans - Pole  scene8f63.html
# ..                 ...             ...
# 56            Tomatoes  sceneea10.html
# 57             Turnips  scene0f7d.html
# 58  Vegetable Amaranth  scenea6a1.html
# 59          Watermelon  scenedc02.html
# 60            Zucchini  scene6420.html
#
#                                             url_scene  \
# 0   http://www.gardening.cornell.edu/homegardening...
# 1   http://www.gardening.cornell.edu/homegardening...
# 2   http://www.gardening.cornell.edu/homegardening...
# 3   http://www.gardening.cornell.edu/homegardening...
# 4   http://www.gardening.cornell.edu/homegardening...
# ..                                                ...
# 56  http://www.gardening.cornell.edu/homegardening...
# 57  http://www.gardening.cornell.edu/homegardening...
# 58  http://www.gardening.cornell.edu/homegardening...
# 59  http://www.gardening.cornell.edu/homegardening...
# 60  http://www.gardening.cornell.edu/homegardening...
#
#                                                season  \
# 0                     Vegetable (Cool Season) - Other
# 1              Vegetable (Cool Season) - Salad Greens
# 2                     Vegetable (Cool Season) - Other
# 3                     Vegetable (Warm Season) - Other
# 4                     Vegetable (Warm Season) - Other
# ..                                                ...
# 56  Vegetable (Warm Season) - Tomatoes, Peppers, E...
# 57           Vegetable (Cool Season) - Cabbage Family
# 58             Vegetable (Warm Season) - Salad Greens
# 59                 Vegetable (Warm Season) - Cucurbit
# 60                 Vegetable (Warm Season) - Cucurbit
#
#                     scientific_name                             family  \
# 0                   Cynara scolymus                         Compositae
# 1                   Eruca vesicaria                       Brassicaceae
# 2            Asparagus officianalis                          Liliaceae
# 3   Phaseolus vulgaris (Bush beans)                           Fabaceae
# 4   Phaseolus vulgaris (Pole beans)                           Fabaceae
# ..                              ...                                ...
# 56          Lycopersicon esculentum                         Solanaceae
# 57          Brassica rapa var. rapa  Vegetable (Cool Season) - Cabbage
# 58              Amaranthus tricolor                      Amaranthaceae
# 59                Citrullus lanatus                      Cucurbitaceae
# 60                   Cucurbita pepo                      Cucurbitaceae
#
#                                           description              sunlight  \
# 0   This cool-season perennial prized for its flav...              full sun
# 1   This fast-growing cool-season salad green - of...  full sun\npart shade
# 2   Among the earliest crops in spring, plantings ...  full sun\npart shade
# 3   You can harvest this staple of the vegetable g...              full sun
# 4   Note: There are other species of beans with cl...              full sun
# ..                                                ...                   ...
# 56  The most popular garden vegetable crop, tomato...              full sun
# 57  Fast-growing spring turnip crops are best harv...  full sun\npart shade
# 58  This warm-season salad green can help fill the...              full sun
# 59  Heat-loving watermelons can be a challenge to ...              full sun
# 60  Summer squash comes in a variety of shapes and...              full sun
#
#                                       soil conditions hardiness  ...  \
# 0                          requires well-drained soil    6 to 9  ...
# 1                             tolerates low fertility      None  ...
# 2   tolerates acid soil\ntolerates droughty soil\n...    2 to 8  ...
# 3                          requires well-drained soil      None  ...
# 4                          requires well-drained soil      None  ...
# ..                                                ...       ...  ...
# 56    tolerates acid soil\nrequires well-drained soil      None  ...
# 57                         requires well-drained soil      None  ...
# 58                            tolerates low fertility      None  ...
# 59                            requires high fertility      None  ...
# 60  requires well-drained soil\nrequires high fert...      None  ...
#
#    foliage colors foliage texture  \
# 0     light green          medium
# 1    medium green          medium
# 2     light green            fine
# 3    medium green          medium
# 4    medium green          medium
# ..            ...             ...
# 56   medium green          medium
# 57   medium green          medium
# 58                         medium
# 59   medium green          coarse
# 60   medium green          coarse
#
#                                             tolerates  \
# 0   frost - Tolerates heavy frost, but heavy frost...
# 1                                               frost
# 2                                                salt
# 3                                                None
# 4                                                None
# ..                                                ...
# 56                                               None
# 57  frost - Light frost improves flavor, but hard ...
# 58                                               heat
# 59                                               None
# 60                                               None
#
#                               special characteristics  \
# 0                         not native to North America
# 1                         not native to North America
# 2   not native to North America - Mediterranean.be...
# 3   not native to North America - Species has been...
# 4   native to North America - Species has been und...
# ..                                                ...
# 56  native to North America - Tomatoes were probab...
# 57  not native to North America - Not known in the...
# 58  not native to North America - Native to tropic...
# 59                        not native to North America
# 60                            native to North America
#
#                                           how to grow  \
# 0   Propagate by seed,division or separation- Seed...
# 1                                  Propagate by seed
# 2   Propagate by seed, division or separation - Pu...
# 3   Propagate by seed- Do not start seeds inside. ...
# 4   Propagate by seed- Do not start seeds inside.B...
# ..                                                ...
# 56                                 Propagate by seed
# 57                                 Propagate by seed
# 58
# 59                                 Propagate by seed
# 60                                 Propagate by seed
#
#                               germination temperature  \
# 0                                       70 F to 80 F
# 1                                       40 F to 55 F
# 2                                       70 F to 77 F
# 3    70 F to 80 F  - Germination is slow and poor ...
# 4    70 F to 80 F  - Germination is slow and poor ...
# ..                                                ...
# 56   60 F to 95 F  - Germinates best at 75 F to 90...
# 57   45 F to 85 F  - Will germinate at soil temper...
# 58   70 F to 75 F  - Germinates best at soil tempe...
# 59                                      60 F to 95 F
# 60   60 F to 105 F - Will not germinate in cold so...
#
#                                        emergence days  \
# 0                                            8 to 12
# 1                                             5 to 7
# 2                                           10 to 12
# 3    8 to 10  - Germination may take two weeks or ...
# 4    8 to 10  - Germination may take two weeks or ...
# ..                                                ...
# 56                   6 to 12  - About 1 week at 75 F.
# 57                                            4 to 7
# 58
# 59   3 to 5  - In very warm (90 F) soil.  About 10...
# 60   5 to 10  - Should germinate in less than a we...
#
#                 seed save time  \
# 0   Seed can be saved 6 years.
# 1   Seed can be saved 5 years.
# 2   Seed can be saved 3 years.
# 3   Seed can be saved 5 years.
# 4   Seed can be saved 5 years.
# ..                         ...
# 56
# 57  Seed can be saved 4 years.
# 58
# 59  Seed can be saved 4 years.
# 60  Seed can be saved 6 years.
#
#                                      Maintenance Info  \
# 0   Plant root divisions (basal stem pieces with a...
# 1   Seeds germinate quickly even in cold soil.  Pl...
# 2   Carefully consider site before planting this l...
# 3   Do not plant until danger of frost has passed ...
# 4   Do not plant until danger of frost has passed ...
# ..                                                ...
# 56  If you purchase transplants, look for sturdy, ...
# 57  From early spring to late summer, sow seeds ¼ ...
# 58  Sow outside in late spring or early summer app...
# 59  If you have long, hot growing seasons direct-s...
# 60  Squash like warm soil and are very sensitive t...
#
#                                                 Pests
# 0   Aphids - A hard stream of water can be used to...
# 1                                        Flea beetles
# 2   Asparagus beetles (common and spotted) - Handp...
# 3   Mexican bean beetles - Handpick and destroy be...
# 4   Mexican bean beetles - Handpick and destroy be...
# ..                                                ...
# 56  Tomato hornworms - Hand pick larvae.  This pes...
# 57  Flea beetles - Use row covers to help protect ...
# 58
# 59  Striped or spotted cucumber beetles - Construc...
# 60  Squash bug - Hand pick.  Bury or compost plant...
#
# [61 rows x 22 columns]

# %% [markdown]
# # Adding QR Code to database

# %%
import qrcode

# %%
len(df)
# Out:
# 61

# %%
#Do not need to run again
#qr_codes = []
#for i in range(len(df)):
 #   img = qrcode.make(df.loc[i, "veggie"])
  #  img.save(df.loc[i, "veggie"]+'.png')

# %%
QR_code_list = ['https://drive.google.com/file/d/1wPlMP0I6IIbUcdU8K4g-hRuyALcOy2dC/view?usp=sharing',
           'https://drive.google.com/file/d/1aqB3o6Km2ccJWJuhkmJTVLvEFV6Gpj8I/view?usp=sharing',
           'https://drive.google.com/file/d/1t8g74Js6k2gw1tyZ9RXQGsi8tQMt0Dkh/view?usp=sharing',
           'https://drive.google.com/file/d/1_Zr_GjUOWUYk_QocKneXF_Gws2lR99de/view?usp=sharing',
           'https://drive.google.com/file/d/1I9DUenRgxOCEc2BoELzivIPYxZkxfRoL/view?usp=sharing',
           'https://drive.google.com/file/d/1rM0rsybpxh2GaCbxxQNkNOKX3QcLM0U_/view?usp=sharing',
           'https://drive.google.com/file/d/1PH1KJEVIqoIe9ndPvCSfNgnf5y3N9bk8/view?usp=sharing',
           'https://drive.google.com/file/d/16yv6zz2owtU-G39V1YylB7EWvodaA3ty/view?usp=sharing',
           'https://drive.google.com/file/d/1N56t5uVUrNy5PNrwVc3eGxdPGgbdkskN/view?usp=sharing',
           'https://drive.google.com/file/d/1pGdNTtMuEHj4JKSFquBHZ0A7ZqRd2oDX/view?usp=sharing',
           'https://drive.google.com/file/d/1huw7ucD7lcQtXKmP234NKN4JqauuOq3b/view?usp=sharing',
           'https://drive.google.com/file/d/1kn3m3U04jNrSKYXCMtryzwirR4rKDWIw/view?usp=sharing',
           'https://drive.google.com/file/d/17VVdny3Umgo6nIQLurF7v1jh6ijO7dy3/view?usp=sharing',
           'https://drive.google.com/file/d/1o5fRyUGJvjW4kR8wbkQS79LdJH4b7g5z/view?usp=sharing',
           'https://drive.google.com/file/d/1WoFVxx944OJoXOPhFuSZkk-_So-Jv3At/view?usp=sharing',
           'https://drive.google.com/file/d/1c_dXPIaRSnGhsCvPDGx3wMlWSzCfwEOM/view?usp=sharing',
           'https://drive.google.com/file/d/1Lidh_B8ShJY0rRrL4S2qfqGsWccUq1pG/view?usp=sharing',
           'https://drive.google.com/file/d/1lkVkQOh8b4ULvm1Sb1tnCqYbXO5Y_0Zy/view?usp=sharing',
           'https://drive.google.com/file/d/1CoYfWkphrmc7SIO1jQrScr3bWH8FFBc-/view?usp=sharing',
           'https://drive.google.com/file/d/1sKi4e4MTI4DjomIP6vP6_esh10nxGxGc/view?usp=sharing',
           'https://drive.google.com/file/d/1igFG5Gf3k1LQG0P3naDAov7Y_2Ls7Y7s/view?usp=sharing',
           'https://drive.google.com/file/d/1aBxe3rv4ICXTaHtIU-i_Oidqlp8U3ZOj/view?usp=sharing',
           'https://drive.google.com/file/d/1vnu84wt5YOzxRdX7PYz7Vqo-fQlv5sO7/view?usp=sharing',
           'https://drive.google.com/file/d/1Qu46JTaua0GW2l-YVk_-h_9Z9g3RL5Pq/view?usp=sharing',
           'https://drive.google.com/file/d/1XMKPY0yiMMlT-8UaINtlSS4e6gLQPW6a/view?usp=sharing',
           'https://drive.google.com/file/d/1qhNduUqaWOsMCWczNdtKsqSLvMyyNtFa/view?usp=sharing',
           'https://drive.google.com/file/d/1ccfunh86_SizzikxlXVVs-O0wCaWgyaf/view?usp=sharing',
           'https://drive.google.com/file/d/1PgB2t4eKYq2AcpHk1JU7VQxrYY1gfsau/view?usp=sharing',
           'https://drive.google.com/file/d/1dwhVXYJc-2p-SLt3WlunsNoSnU6WQ8qo/view?usp=sharing',
           'https://drive.google.com/file/d/15LVeN_VMgAVeoBPrdYSAXsM4p51Y5rQ6/view?usp=sharing',
           'https://drive.google.com/file/d/1wv-K9yY1G9frA92TxR2aJFvwa5Cww3bi/view?usp=sharing',
           'https://drive.google.com/file/d/11U3jMHw0a70UomnDlbOIDMyAR9EUhMfr/view?usp=sharing',
           'https://drive.google.com/file/d/1Rv-x4C30pO6hC6rYkOyOKb5MWM6iJ0s3/view?usp=sharing',
           'https://drive.google.com/file/d/17a1_a0SqLZi5wrbbXQVoo4ojauZrsg5a/view?usp=sharing',
           'https://drive.google.com/file/d/19NgTVEW1R7KhDtY0ZIR6y1K6_IsmPNfG/view?usp=sharing',
           'https://drive.google.com/file/d/1gqbkTlBAXlFe5OwWgmG3xPpHsXOAG9Hv/view?usp=sharing',
           'https://drive.google.com/file/d/1GkTpvqqc4KHUlED5RnaCA4i2ZuvkMH2C/view?usp=sharing',
           'https://drive.google.com/file/d/1egK6LWSiKeDerNFoMk8B4viY3zZR-VRb/view?usp=sharing',
           'https://drive.google.com/file/d/1glgjERoqu-TXNhZx7o7EZ7ERllByvD8M/view?usp=sharing',
           'https://drive.google.com/file/d/1-k57hn1MmIfTk1vX51W2KSvre8lcaP6H/view?usp=sharing',
           'https://drive.google.com/file/d/1pECpOIN3WwJO475R9Yp8JG5KPuoEPy87/view?usp=sharing',
           'https://drive.google.com/file/d/1ByK1NlKYKoaT9fSYOLl0BSTbmuUEohVO/view?usp=sharing',
           'https://drive.google.com/file/d/1DewDcwoFPql2PqVojMa5eXipXLYV3Wqv/view?usp=sharing',
           'https://drive.google.com/file/d/11Qe8aytGxbtwj8POA-B5Dh_XPvYyAAsq/view?usp=sharing',
           'https://drive.google.com/file/d/1aLKWcajfVZCCmbQV-r7C0Ukd1y6bRzi1/view?usp=sharing',
           'https://drive.google.com/file/d/1SkXg4I9WtnxXuVE7UejpDEUB_4Mu0s9q/view?usp=sharing',
           'https://drive.google.com/file/d/148ABqRETm0yCxWZ2FmHOrPUEBX8b_1FP/view?usp=sharing',
           'https://drive.google.com/file/d/1Obs87GfiI2_haMS-6xKCFkYQQ3SfYOuV/view?usp=sharing',
           'https://drive.google.com/file/d/1s0jnwS-5gF2JZrkj7MrZuCujrPRvvt9y/view?usp=sharing',
           'https://drive.google.com/file/d/1COa4Tuei9sIwwzcv-bEiqcve5FtmbsEm/view?usp=sharing',
           'https://drive.google.com/file/d/1ALGh4uk6saJcuacpAFmsP9O80glYvyGZ/view?usp=sharing',
           'https://drive.google.com/file/d/181bzgb9AbW1VgsvJxBBftgHydnXN7rt_/view?usp=sharing',
           'https://drive.google.com/file/d/1j7nzi9Dogxobs_D43AgSsEgCqrB5dL2U/view?usp=sharing',
           'https://drive.google.com/file/d/1upoBef_fDxjFRGR5XsB2E-0NrHdJBbO-/view?usp=sharing',
           'https://drive.google.com/file/d/135AbaU7umIJptru52XZE83M4Q_nCCDbd/view?usp=sharing',
           'https://drive.google.com/file/d/1Cl0lf2ODq6oa6vzvZ6ejMBGAFe0GjloI/view?usp=sharing',
           'https://drive.google.com/file/d/10bwx4zYxE29QppZ6UPAkDTcZeJA-8hic/view?usp=sharing',
           'https://drive.google.com/file/d/1ttRJGN35s8j9ErzUO7WtE3cOySII7QDX/view?usp=sharing',
           'https://drive.google.com/file/d/1yJRXn2uexZbe8dOgQYqMo3_2EfBGmZNh/view?usp=sharing',
           'https://drive.google.com/file/d/1JdN5Qx20N3OETMyADjeoxKS8qZJRZbfu/view?usp=sharing',
           'https://drive.google.com/file/d/1hWmIA9jp4iV2cAFEshyAvMlPPOwZBHqS/view?usp=sharing']

# %%
df.insert(0, "QR Code",QR_code_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-701-b462b43e6eb9> in <module>
# ----> 1 df.insert(0, "QR Code",QR_code_list)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3589         self._ensure_valid_index(value)
#    3590         value = self._sanitize_column(column, value, broadcast=False)
# -> 3591         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3592
#    3593     def assign(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# -> 1173             raise ValueError("cannot insert {}, already exists".format(item))
#    1174
#    1175         if not isinstance(loc, int):
#
# ValueError: cannot insert QR Code, already exists

# %%
df
# Out:
#                                               QR Code              veggie  \
# 0   https://drive.google.com/file/d/1wPlMP0I6IIbUc...   Artichoke - Globe
# 1   https://drive.google.com/file/d/1aqB3o6Km2ccJW...             Arugula
# 2   https://drive.google.com/file/d/1t8g74Js6k2gw1...           Asparagus
# 3   https://drive.google.com/file/d/1_Zr_GjUOWUYk_...        Beans - Bush
# 4   https://drive.google.com/file/d/1I9DUenRgxOCEc...        Beans - Pole
# ..                                                ...                 ...
# 56  https://drive.google.com/file/d/10bwx4zYxE29Qp...            Tomatoes
# 57  https://drive.google.com/file/d/1ttRJGN35s8j9E...             Turnips
# 58  https://drive.google.com/file/d/1yJRXn2uexZbe8...  Vegetable Amaranth
# 59  https://drive.google.com/file/d/1JdN5Qx20N3OET...          Watermelon
# 60  https://drive.google.com/file/d/1hWmIA9jp4iV2c...            Zucchini
#
#              scene                                          url_scene  \
# 0   scenec09b.html  http://www.gardening.cornell.edu/homegardening...
# 1   scene3693.html  http://www.gardening.cornell.edu/homegardening...
# 2   scenee3ed.html  http://www.gardening.cornell.edu/homegardening...
# 3   scenef57c.html  http://www.gardening.cornell.edu/homegardening...
# 4   scene8f63.html  http://www.gardening.cornell.edu/homegardening...
# ..             ...                                                ...
# 56  sceneea10.html  http://www.gardening.cornell.edu/homegardening...
# 57  scene0f7d.html  http://www.gardening.cornell.edu/homegardening...
# 58  scenea6a1.html  http://www.gardening.cornell.edu/homegardening...
# 59  scenedc02.html  http://www.gardening.cornell.edu/homegardening...
# 60  scene6420.html  http://www.gardening.cornell.edu/homegardening...
#
#                                                season  \
# 0                     Vegetable (Cool Season) - Other
# 1              Vegetable (Cool Season) - Salad Greens
# 2                     Vegetable (Cool Season) - Other
# 3                     Vegetable (Warm Season) - Other
# 4                     Vegetable (Warm Season) - Other
# ..                                                ...
# 56  Vegetable (Warm Season) - Tomatoes, Peppers, E...
# 57           Vegetable (Cool Season) - Cabbage Family
# 58             Vegetable (Warm Season) - Salad Greens
# 59                 Vegetable (Warm Season) - Cucurbit
# 60                 Vegetable (Warm Season) - Cucurbit
#
#                     scientific_name                             family  \
# 0                   Cynara scolymus                         Compositae
# 1                   Eruca vesicaria                       Brassicaceae
# 2            Asparagus officianalis                          Liliaceae
# 3   Phaseolus vulgaris (Bush beans)                           Fabaceae
# 4   Phaseolus vulgaris (Pole beans)                           Fabaceae
# ..                              ...                                ...
# 56          Lycopersicon esculentum                         Solanaceae
# 57          Brassica rapa var. rapa  Vegetable (Cool Season) - Cabbage
# 58              Amaranthus tricolor                      Amaranthaceae
# 59                Citrullus lanatus                      Cucurbitaceae
# 60                   Cucurbita pepo                      Cucurbitaceae
#
#                                           description              sunlight  \
# 0   This cool-season perennial prized for its flav...              full sun
# 1   This fast-growing cool-season salad green - of...  full sun\npart shade
# 2   Among the earliest crops in spring, plantings ...  full sun\npart shade
# 3   You can harvest this staple of the vegetable g...              full sun
# 4   Note: There are other species of beans with cl...              full sun
# ..                                                ...                   ...
# 56  The most popular garden vegetable crop, tomato...              full sun
# 57  Fast-growing spring turnip crops are best harv...  full sun\npart shade
# 58  This warm-season salad green can help fill the...              full sun
# 59  Heat-loving watermelons can be a challenge to ...              full sun
# 60  Summer squash comes in a variety of shapes and...              full sun
#
#                                       soil conditions  ... foliage colors  \
# 0                          requires well-drained soil  ...    light green
# 1                             tolerates low fertility  ...   medium green
# 2   tolerates acid soil\ntolerates droughty soil\n...  ...    light green
# 3                          requires well-drained soil  ...   medium green
# 4                          requires well-drained soil  ...   medium green
# ..                                                ...  ...            ...
# 56    tolerates acid soil\nrequires well-drained soil  ...   medium green
# 57                         requires well-drained soil  ...   medium green
# 58                            tolerates low fertility  ...
# 59                            requires high fertility  ...   medium green
# 60  requires well-drained soil\nrequires high fert...  ...   medium green
#
#    foliage texture                                          tolerates  \
# 0           medium  frost - Tolerates heavy frost, but heavy frost...
# 1           medium                                              frost
# 2             fine                                               salt
# 3           medium                                               None
# 4           medium                                               None
# ..             ...                                                ...
# 56          medium                                               None
# 57          medium  frost - Light frost improves flavor, but hard ...
# 58          medium                                               heat
# 59          coarse                                               None
# 60          coarse                                               None
#
#                               special characteristics  \
# 0                         not native to North America
# 1                         not native to North America
# 2   not native to North America - Mediterranean.be...
# 3   not native to North America - Species has been...
# 4   native to North America - Species has been und...
# ..                                                ...
# 56  native to North America - Tomatoes were probab...
# 57  not native to North America - Not known in the...
# 58  not native to North America - Native to tropic...
# 59                        not native to North America
# 60                            native to North America
#
#                                           how to grow  \
# 0   Propagate by seed,division or separation- Seed...
# 1                                  Propagate by seed
# 2   Propagate by seed, division or separation - Pu...
# 3   Propagate by seed- Do not start seeds inside. ...
# 4   Propagate by seed- Do not start seeds inside.B...
# ..                                                ...
# 56                                 Propagate by seed
# 57                                 Propagate by seed
# 58
# 59                                 Propagate by seed
# 60                                 Propagate by seed
#
#                               germination temperature  \
# 0                                       70 F to 80 F
# 1                                       40 F to 55 F
# 2                                       70 F to 77 F
# 3    70 F to 80 F  - Germination is slow and poor ...
# 4    70 F to 80 F  - Germination is slow and poor ...
# ..                                                ...
# 56   60 F to 95 F  - Germinates best at 75 F to 90...
# 57   45 F to 85 F  - Will germinate at soil temper...
# 58   70 F to 75 F  - Germinates best at soil tempe...
# 59                                      60 F to 95 F
# 60   60 F to 105 F - Will not germinate in cold so...
#
#                                        emergence days  \
# 0                                            8 to 12
# 1                                             5 to 7
# 2                                           10 to 12
# 3    8 to 10  - Germination may take two weeks or ...
# 4    8 to 10  - Germination may take two weeks or ...
# ..                                                ...
# 56                   6 to 12  - About 1 week at 75 F.
# 57                                            4 to 7
# 58
# 59   3 to 5  - In very warm (90 F) soil.  About 10...
# 60   5 to 10  - Should germinate in less than a we...
#
#                 seed save time  \
# 0   Seed can be saved 6 years.
# 1   Seed can be saved 5 years.
# 2   Seed can be saved 3 years.
# 3   Seed can be saved 5 years.
# 4   Seed can be saved 5 years.
# ..                         ...
# 56
# 57  Seed can be saved 4 years.
# 58
# 59  Seed can be saved 4 years.
# 60  Seed can be saved 6 years.
#
#                                      Maintenance Info  \
# 0   Plant root divisions (basal stem pieces with a...
# 1   Seeds germinate quickly even in cold soil.  Pl...
# 2   Carefully consider site before planting this l...
# 3   Do not plant until danger of frost has passed ...
# 4   Do not plant until danger of frost has passed ...
# ..                                                ...
# 56  If you purchase transplants, look for sturdy, ...
# 57  From early spring to late summer, sow seeds ¼ ...
# 58  Sow outside in late spring or early summer app...
# 59  If you have long, hot growing seasons direct-s...
# 60  Squash like warm soil and are very sensitive t...
#
#                                                 Pests
# 0   Aphids - A hard stream of water can be used to...
# 1                                        Flea beetles
# 2   Asparagus beetles (common and spotted) - Handp...
# 3   Mexican bean beetles - Handpick and destroy be...
# 4   Mexican bean beetles - Handpick and destroy be...
# ..                                                ...
# 56  Tomato hornworms - Hand pick larvae.  This pes...
# 57  Flea beetles - Use row covers to help protect ...
# 58
# 59  Striped or spotted cucumber beetles - Construc...
# 60  Squash bug - Hand pick.  Bury or compost plant...
#
# [61 rows x 23 columns]

# %%
df.to_csv('veggies_df.csv')
